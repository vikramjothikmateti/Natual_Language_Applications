# %% [markdown]
# # Phase1:
# Finally, you need to write a code to read the JSON file(s) of your NER tags in Python to be able to use them in step 3.

# %%
import json

def read_ner_json(file_path):
    with open(file_path, 'r') as file:
        data = json.load(file)
        
    # Loop through each tweet in the JSON file
    for annotation in data['annotations']:
        text = annotation[0]
        entities = annotation[1]['entities']
        
        print("Tweet:", text)
        print("Entities:")
        
        # Loop through each entity and print its text and type
        for start, end, entity_type in entities:
            entity_text = text[start:end]
            print(f"  - {entity_text}: {entity_type}")
        print()

# loading the json file
file_path = 'D:\\masters\\NLP\\All_tweets.json'
read_ner_json(file_path)
# Out:
# Tweet: Moldova will pay $ 110 per 1,000 cubic meters of natural gas over the next four months .
# Entities:
#   - Moldova: GPE
#   -  $ 110: MONEY
#   -  four months: DATE
#
# Tweet: Talks on a fixed price will continue .
# Entities:
#
# Tweet: Moldova had been paying $ 80 for gas .
# Entities:
#   - Moldova: GPE
#   - $ 80: MONEY
#
# Tweet: Russia 's state-owned natural gas company , Gazprom , wanted to double the price to bring Moldova in line with the world market .
# Entities:
#   - Russia: GPE
#   - Gazprom: ORG
#   - Moldova: GPE
#
# Tweet: Gazprom cut supplies to Moldova January 1 .
# Entities:
#   - Gazprom: ORG
#   - Moldova: GPE
#   - January 1: DATE
#
# Tweet: Russia also cut supplies to Ukraine the same day .
# Entities:
#   - Russia: GPE
#   -  Ukraine: GPE
#   - the same day: DATE
#
# Tweet: That dispute was settled three days later .
# Entities:
#   - three days later: DATE
#
# Tweet: Police in the western Indian state of Maharashtra say 26 women drowned after two boats capsized in the Wainganga River late Saturday .
# Entities:
#   - Indian: NORP
#   - Maharashtra: GPE
#   -  Wainganga River: LOC
#   -  Saturday: DATE
#
# Tweet: Local authorities say four women and two crew members managed to swim to safety , but that eight women are still missing .
# Entities:
#   - Local authorities: ORG
#   - women: PERSON
#   - crew members: PERSON
#
# Tweet: Police say the women - poor farm laborers on their way home from work - started panicking after seeing a bolt of lightning .
# Entities:
#   - Police: ORG
#   - women: PERSON
#   - farm laborers: PERSON
#
# Tweet: Their panicked movements caused the boats to capsize .
# Entities:
#
# Tweet: The accident happened in Bhandara district , some 925 kilometers northeast of the state capital , Mumbai .
# Entities:
#   - Bhandara district: GPE
#   - 925 kilometers northeast : LOC
#   -  Mumbai: GPE
#
# Tweet: President Bush has telephoned his Afghan counterpart Hamid Karzai to express his support for Sunday 's legislative elections .
# Entities:
#   - President Bush: PERSON
#   - Afghan: NORP
#   - Hamid Karzai: PERSON
#   - Sunday: DATE
#
# Tweet: A White House spokesman says Mr. Karzai told President Bush that his nation was ready to vote , and that the people of Afghanistan were enthusiastic about the polls .
# Entities:
#   - White House: ORG
#   -  Mr. Karzai : PERSON
#   - President Bush: PERSON
#   - Afghanistan: GPE
#
# Tweet: The Afghan leader also invited Mr. Bush to visit and address the new parliament once it convenes .
# Entities:
#   -  Afghan: NORP
#   -  Mr. Bush: PERSON
#   - parliament: ORG
#
# Tweet: Meanwhile , the election campaign in Afghanistan has officially ended , with candidates making their final pitches .
# Entities:
#   - Afghanistan: GPE
#
# Tweet: With campaigning forbidden 48 hours before the polls open , candidates scrambled to woo voters , while organizers raced to spread their message on how to cast the ballots .
# Entities:
#   - 48 hours: DATE
#
# Tweet: More than 12 million Afghans are registered to vote Sunday to elect a national parliament and local councils in all 34 provinces .
# Entities:
#   - Afghans: NORP
#   - Sunday: DATE
#   - provinces: LOC
#
# Tweet: Afghan officials say at least six suspected Taleban militants have been killed and 15 arrested , including one of the militia 's commanders , in separate incidents in southern Afghanistan .
# Entities:
#   - Afghan: NORP
#   - Taleban: ORG
#   - Afghanistan: GPE
#
# Tweet: The six insurgents were killed Sunday as they fled after attacking a security post close to Tirin Kot , the capital of restive Uruzgan province .
# Entities:
#   - Sunday: DATE
#   - Tirin Kot: GPE
#   - Uruzgan: GPE
#
# Tweet: The officials say the Afghan National Army and US-led forces also captured 9 suspected Taleban fighters , including local commander Mullah Janan , in a village near Tirin Kot , and six others were arrested in another district of Uruzgan province .
# Entities:
#   - Afghan National Army : ORG
#   - US-led forces: ORG
#   - Taleban: ORG
#   - Mullah Janan: PERSON
#   -  Tirin Kot : LOC
#   - Uruzgan: GPE
#
# Tweet: Meanwhile , in the Souray district of neighboring Zabul province , one suspected Taleban rebel was killed and one was wounded by a bomb they were planting on a road used by Afghan and US forces .
# Entities:
#   - Souray district: LOC
#   - Zabul province: GPE
#   - Taleban: ORG
#   - Afghan: NORP
#   - US: NORP
#
# Tweet: Violence has surged ahead of next month 's parliamentary elections in Afghanistan .
# Entities:
#   - next month: DATE
#   - Afghanistan: GPE
#
# Tweet: The U.S. dollar hit record lows against the euro Tuesday .
# Entities:
#   - U.S. dollar: MONEY
#   - euro: MONEY
#   - Tuesday: DATE
#
# Tweet: It took more than one dollar and 48 cents to buy one euro .
# Entities:
#   - one dollar: MONEY
#   - 48 cents: MONEY
#   - one euro: MONEY
#
# Tweet: The dollar has been battered by a series of problems , including continuing gloom in the key U.S. housing sector , and the slowing U.S. economy .
# Entities:
#   - dollar: MONEY
#   - U.S.: GPE
#   -  U.S.: GPE
#
# Tweet: Some speculators are selling dollars because they expect the U.S. central bank will try to stimulate the economy by cutting interest rates again soon .
# Entities:
#   - dollars: MONEY
#   - U.S.: GPE
#
# Tweet: Lower U.S. interest rates can cut the return on some investments .
# Entities:
#   - U.S.: GPE
#
# Tweet: The falling dollar is prompting some oil-rich nations around the Persian Gulf to consider ending the practice of linking the value of their currencies to that of the dollar and instead peg the value to a " basket " of other currencies .
# Entities:
#   - dollar: MONEY
#   - oil-rich nations: GPE
#   -  Persian Gulf: GPE
#   - dollar: MONEY
#
# Tweet: Such a move would reduce demand for dollars , and further weaken the U.S. currency .
# Entities:
#   - dollars: MONEY
#   - U.S.: GPE
#
# Tweet: Afghan officials say suspected Taleban insurgents have killed two more pro-government Muslim clerics , just days after a bomb Friday killed a mullah in a mosque in the eastern Khost province .
# Entities:
#   - Afghan: GPE
#   - Taleban: ORG
#   - Friday: DATE
#   - Khost: GPE
#
# Tweet: The officials say Mullah Mohammad Gul was gunned down late Sunday while walking home after prayers at a mosque in Lashkargah , the capital of southern Helmand province .
# Entities:
#   - Mullah Mohammad Gul: PERSON
#   - Sunday: DATE
#   - Lashkargah: LOC
#   - Helmand: GPE
#
# Tweet: Hours later , unknown assailants broke into a home of the head of the religious council for eastern Kunar province , Noor Ahmad Jan , and shot him dead .
# Entities:
#   - Kunar: GPE
#   - Noor Ahmad Jan : PERSON
#
# Tweet: Following the Friday killing , at least 5,000 Afghans staged a peaceful protest in Khost , urging the government to provide better security for religious leaders .
# Entities:
#   - Friday: DATE
#   - Afghans: NORP
#   - Khost: GPE
#
# Tweet: In the past , Taleban insurgents have killed several influential clerics who had denounced the militants and expressed support for President Hamid Karzai .
# Entities:
#   - Taleban: ORG
#   -  President Hamid Karzai : PERSON
#
# Tweet: The man who trained 1,000 white pigeons to be released over Hanoi on the city 's 1,000-year anniversary says more than half the birds have been killed - many to appear on Vietnamese dinner tables .
# Entities:
#   - Hanoi: GPE
#   - 1,000-year anniversary : DATE
#   - Vietnamese: NORP
#
# Tweet: In recent interviews , Pham Tai Thu has expressed his disappointment at the loss of the birds , which he had hoped would thrive as a lasting symbol of peace .
# Entities:
#   - Pham Tai Thu: PERSON
#
# Tweet: He said some of the birds have been poisoned or died of diseases , while others were captured and sold to restaurants .
# Entities:
#
# Tweet: Thu said he painstakingly raised the birds and trained them to return to the Hanoi Botanical Garden after their release during the city 's anniversary ceremonies in early October .
# Entities:
#   - Thu: PERSON
#   - Hanoi: GPE
#   - October: DATE
#
# Tweet: He said he had hoped they would create large flocks to represent the city 's emergence from decades of war .
# Entities:
#
# Tweet: United Nations Secretary-General Kofi Annan is expected to ask for manpower and equipment for a peacekeeping force for Sudan when he meets with President Bush later Monday .
# Entities:
#   - United Nations: ORG
#   - Kofi Annan: PERSON
#   - Sudan: GPE
#   - President Bush: PERSON
#   - Monday: DATE
#
# Tweet: Mr. Annan is scheduled to meet with Mr. Bush at the White House to discuss a peacekeeping mission for Sudan 's war-torn Darfur region .
# Entities:
#   - Mr. Annan: PERSON
#   - Mr. Bush: PERSON
#   - White House: LOC
#   - Sudan: GPE
#   - Darfur: LOC
#
# Tweet: The peacekeeping force has been mandated by the U.N. Security Council to take over from an African Union force of seven thousand .
# Entities:
#   - U.N. Security Council: ORG
#   -  African Union: ORG
#
# Tweet: Last week , Mr. Annan said the U.N. force will have to be bigger and better equipped , which , he said , will require the participation of big and powerful countries with highly trained troops - including the U.S. U.S. officials have said they hope to arrange a U.N. mission to Darfur by the end of this month .
# Entities:
#   - Mr. Annan: PERSON
#   - U.N.: ORG
#   - U.S.: GPE
#   - U.S.: GPE
#   - U.N.: ORG
#   - Darfur: GPE
#   - month: DATE
#
# Tweet: Fighting between rebel and government forces in Darfur has killed tens of thousands and displaced two million
# Entities:
#   - Darfur: GPE
#
# Tweet: A North Korean cargo ship has dropped anchor in the South Korean port of Ulsan , marking the first visit of its kind in more than two decades .
# Entities:
#   - North Korean: NORP
#   - South Korean: NORP
#   - Ulsan: GPE
#   - two decades: DATE
#
# Tweet: The ship will be loaded with fertilizer intended to help the North deal with perpetual food shortages .
# Entities:
#   - North: GPE
#
# Tweet: South Korea agreed to give 2,00,000 tons of fertilizer to the North after four days of bilateral talks concluded last week .
# Entities:
#   - South Korea: GPE
#   - North: GPE
#   -  four days: DATE
#   - last week: DATE
#
# Tweet: Two more North Korean vessels are expected to cross into South Korean waters later today and early Monday .
# Entities:
#   - North Korean: NORP
#   -  South Korean: NORP
#   - today: DATE
#   - Monday: DATE
#
# Tweet: South Korea began shipping fertilizer by land on Saturday when several trucks crossed the heavily fortified Demilitarized Zone between the two Koreas .
# Entities:
#   - South Korea: GPE
#   - Saturday: DATE
#   - Demilitarized Zone: LOC
#   - Koreas: GPE
#
# Tweet: Some of information for this report provided by AFP .
# Entities:
#   - AFP: ORG
#
# Tweet: Fans of The Sopranos can now own a little piece of the much-honored TV series : bricks from mobster Tony Soprano 's fictional hangout , Satriale 's Pork Store .
# Entities:
#   - The Sopranos: ORG
#   - Tony Soprano: PERSON
#   - Satriale 's Pork Store: ORG
#
# Tweet: Manny Costeira , who owns the Kearny , New Jersey building , is selling 2,000 white stone bricks online before the structure is demolished next month .
# Entities:
#   - Manny Costeira: PERSON
#   - Kearny: GPE
#   - New Jersey: GPE
#   - next month: DATE
#
# Tweet: A condominum complex called The Soprano will be built on the site .
# Entities:
#   - The Soprano: ORG
#
# Tweet: Costeira said the bricks will sell for $ 25 to $ 50 apiece , and will include a serial number and certificate of authentication .
# Entities:
#   - Costeira: PERSON
#   - $ 25: MONEY
#   - $ 50: MONEY
#
# Tweet: Speaking to The Jersey Journal of Jersey City , Costeira said he 's received a few angry e-mails asking why he 's demolishing the joint where Tony and his pals often gathered .
# Entities:
#   - The Jersey Journal: ORG
#   - Jersey City: GPE
#   - Costeira: PERSON
#   - Tony: PERSON
#
# Tweet: The Sopranos aired its 86th and final episode on June 10 , 2007 .
# Entities:
#   - June 10 , 2007: DATE
#
# Tweet: Pakistani security forces backed by helicopter gunships have pounded suspected militant hideouts near the border with Afghanistan .
# Entities:
#   - Pakistani: NORP
#   - Afghanistan: GPE
#
# Tweet: The violence Friday is the latest in a series of attacks in the North Waziristan area , where the Pakistani military has been battling Taleban and al-Qaida militants .
# Entities:
#   - Friday: DATE
#   - North Waziristan: LOC
#   - Pakistani: NORP
#   - Taleban: NORP
#   - al-Qaida: NORP
#
# Tweet: There has been no official word on casualties .
# Entities:
#
# Tweet: This assault comes as local and military officials continue to search for 16 missing soldiers believed to be kidnapped by Taleban militants .
# Entities:
#   -  military officials: PERSON
#   - soldiers: PERSON
#   - Taleban: NORP
#   - militants: PERSON
#
# Tweet: The men disappeared on Thursday while traveling to a military base in South Waziristan in Pakistan 's northwestern tribal region .
# Entities:
#   - Thursday: DATE
#   - South Waziristan: LOC
#   - Pakistan: GPE
#
# Tweet: Also on Thursday , Pakistani security forces said at least 10 militants were killed during a military operation in North Waziristan .
# Entities:
#   - Thursday: DATE
#   - Pakistani: NORP
#   - militants: PERSON
#   - North Waziristan: LOC
#
# Tweet: A military spokesman says the militants were killed while fleeing the site of a roadside bombing that wounded five soldiers .
# Entities:
#   - military spokesman: PERSON
#   - militants: PERSON
#   - soldiers: PERSON
#
# Tweet: Iran has denied receiving a proposal from Moscow to build a joint uranium enrichment facility in Russia .
# Entities:
#   - Iran: GPE
#   - Moscow: GPE
#   - Russia: GPE
#
# Tweet: An Iranian Foreign Ministry spokesman , Hamid Reza Asefi , told a news conference Sunday that Tehran has received no such proposal , and would only consider proposals that recognize Iran 's right to enrich uranium on its own soil .
# Entities:
#   - Iranian Foreign Ministry: ORG
#   - Hamid Reza Asefi: PERSON
#   - Sunday: DATE
#   - Tehran: GPE
#   - Iran: GPE
#
# Tweet: Russia said Saturday its embassy in Tehran presented Iranian authorities with a note saying its offer to set up a joint uranium enrichment facility in Russia remains valid .
# Entities:
#   - Russia: GPE
#   - Saturday: DATE
#   - embassy: ORG
#   - Tehran : GPE
#   - Iranian: NORP
#   - Russia: GPE
#
# Tweet: Under a deal signed earlier this year , Moscow agreed to supply enriched uranium fuel for Iran 's Bushehr reactor .
# Entities:
#   - earlier this year: DATE
#   - Moscow: GPE
#   - Iran: GPE
#   - Bushehr: LOC
#
# Tweet: But Russia also demanded the return of spent fuel to ensure Tehran did not reprocess it into bomb-grade material .
# Entities:
#   -  : GPE
#   - Tehran: GPE
#
# Tweet: The United States and the European Union say Tehran is using its nuclear program to develop atomic weapons .
# Entities:
#   - United States: ORG
#   - European Union: ORG
#   - Tehran: GPE
#
# Tweet: Iran says it is only for peaceful purposes .
# Entities:
#   - Iran: GPE
#
# Tweet: Led by a group of military families , about 200 people have held a rally in Washington to show support for President Bush and the war in Iraq .
# Entities:
#   - Washington: GPE
#   - President Bush: PERSON
#   - Iraq: GPE
#
# Tweet: The participants gathered on the National Mall Sunday carried banners and signs proclaiming support for the more than 130-thousand U.S. troops deployed in the war-torn country .
# Entities:
#   - National Mall: LOC
#   - Sunday: DATE
#   - U.S.: NORP
#
# Tweet: Speakers hailed the efforts to bring democracy to Iraq and Afghanistan and denounced those who protest against it .
# Entities:
#   - Iraq: GPE
#   - Afghanistan: GPE
#
# Tweet: The rally came a day after 100-thousand people gathered on the Mall , demanding the withdrawal of American troops from Iraq , in the largest such demonstration since the war began .
# Entities:
#   - day: DATE
#   - Mall: LOC
#   - American: NORP
#   - Iraq: GPE
#
# Tweet: Russia 's Economic Development and Trade Minister says leading state firms should stay in the private sector , weeks after a state-owned company gained control of a major private competitor .
# Entities:
#   - Russia: GPE
#   - weeks: DATE
#
# Tweet: In an interview with the Kommersant daily , Minister German Gref said state-owned Rosneft and its new unit Yuganskneftegas should be privatized , in case they become one state-owned company .
# Entities:
#   - Kommersant: ORG
#   - German Gref: PERSON
#   - Rosneft: ORG
#   - Yuganskneftegas: ORG
#
# Tweet: Rosneft gained control of privately-owned Yuganskneftegas last month after a government-ordered auction .
# Entities:
#   - Rosneft: ORG
#   - Yuganskneftegas: ORG
#   - last month: DATE
#
# Tweet: Yuganskneftegas was a leading unit of oil giant Yukos , which was owned by oil tycoon and Kremlin critic Vladimir Khodorkovsky .
# Entities:
#   - Yuganskneftegas: ORG
#   - Yukos: ORG
#   - Vladimir Khodorkovsky: PERSON
#
# Tweet: The purchase has raised fear among liberal economists that the government is nationalizing Russia 's energy industry .
# Entities:
#   - Russia: GPE
#
# Tweet: Mr. Khodorkovsky is in prison on fraud charges .
# Entities:
#   - Mr. Khodorkovsky: PERSON
#
# Tweet: A Kenyan court has released nine Somali men accused of piracy , saying it has no jurisdiction to try their case .
# Entities:
#   - Kenyan: NORP
#   - Somali: NORP
#
# Tweet: High Court Judge Mohammed Ibrahim ordered the men to be released and repatriated Tuesday after saying Kenyan courts could not deal with matters that take place outside of the country .
# Entities:
#   - Mohammed Ibrahim: PERSON
#   - Tuesday: DATE
#   - Kenyan: NORP
#
# Tweet: The nine men were captured by a German naval vessel in the Gulf of Aden in March 2009 after an attack on the German-owned freighter MV Courier .
# Entities:
#   - men: PERSON
#   - German: NORP
#   - Gulf of Aden: NORP
#   -  March 2009: DATE
#   - German: NORP
#   - MV Courier: ORG
#
# Tweet: The ruling comes just days after a separate court released 17 suspected Somali pirates due to lack of evidence .
# Entities:
#   - Somali: NORP
#
# Tweet: More than 100 suspected Somali pirates are currently being held in Kenyan prisons .
# Entities:
#   - Somali: NORP
#   - Kenyan: NORP
#
# Tweet: The death toll from a bomb blast in Indian Kashmir has risen to at least 14 people , after more people succumbed to their injuries .
# Entities:
#   - Indian: NORP
#   - Kashmir: GPE
#
# Tweet: Security officials say the explosion , Monday , at a busy market in Pulwama , south of Srinagar , also wounded more than 70 others and damaged a school , a police station and several shops .
# Entities:
#   - Monday: DATE
#   - Pulwama: GPE
#   - Srinagar: GPE
#
# Tweet: The officials say three soldiers are among the dead .
# Entities:
#
# Tweet: Authorities say the bomb was planted aboard a truck carrying construction materials .
# Entities:
#
# Tweet: The charred remains of a man who they say detonated the explosion was recovered from the scene .
# Entities:
#
# Tweet: Police fired tear gas to disperse mobs of angry and grief-stricken people who poured into the streets of Pulwama to denounce the attack .
# Entities:
#   - Pulwama: GPE
#
# Tweet: No one has claimed responsibility for the bombing .
# Entities:
#
# Tweet: But the French News Agency quotes a military official who blames Islamic militants for the blast .
# Entities:
#   - French News Agency : ORG
#   - Islamic: ORG
#
# Tweet: Recent studies show that children who do not get enough sleep tend to have some emotional problems as well as weight gain later in life .
# Entities:
#
# Tweet: As VOA 's Melinda Smith reports , the research seems to blame the parents .
# Entities:
#   -  VOA : ORG
#   - Melinda Smith: PERSON
#
# Tweet: Pakistani intelligence officials say three U.S. missile strikes have killed at least 11 suspected militants in the country 's North Wazirstan tribal region .
# Entities:
#   - Pakistani: NORP
#   -  U.S.: ORG
#   - North Wazirstan: LOC
#
# Tweet: The first drone strike Wednesday struck a vehicle near the town of Miran Shah , killing at least four militants .
# Entities:
#   - Wednesday: DATE
#   - Miran Shah: LOC
#
# Tweet: Hours later , officials said , a second attack killed three militants in the same region .
# Entities:
#
# Tweet: And a third missile strike hit a vehicle in the Pai Khel area of North Waziristan , killing at least four suspected militants .
# Entities:
#   - Pai Khel: GPE
#   - North Waziristan: GPE
#
# Tweet: The United States has increased its use of missiles launched from unmanned aircraft against Taliban and al-Qaida-linked militants .
# Entities:
#   - United States: GPE
#   - Taliban: NORP
#   -  al-Qaida: NORP
#
# Tweet: There have been at least 40 such strikes since September in northwestern Pakistan near the Afghan border .
# Entities:
#   - September: DATE
#   - Pakistan: GPE
#   - Afghan: NORP
#
# Tweet: The U.S. does not publicly acknowledge the attacks , which often are criticized by Pakistani officials as a violation of their country 's sovereignty .
# Entities:
#   -  U.S.: GPE
#   - Pakistani: NORP
#
# Tweet: The U.S. military says an F15 fighter jet crashed in eastern Afghanistan early Saturday , killing the two crew members on board .
# Entities:
#   - U.S. military: ORG
#   - Afghanistan: GPE
#   - Saturday: DATE
#
# Tweet: A military statement says the plane went down during an operation in the region .
# Entities:
#
# Tweet: The military did not indicate why the plane went down , but the statement said the crash was not caused by " hostile fire . "
# Entities:
#
# Tweet: Coalition forces are engaged in a major offensive in southern Afghanistan to drive Taliban militants out of their strongholds , and to maintain security ahead of a presidential election in August .
# Entities:
#   - Coalition forces: ORG
#   - Afghanistan: GPE
#   - Taliban: ORG
#   - August: DATE
#
# Tweet: On Friday , a roadside bomb killed 11 civilians , including five children , as they were traveling to a shrine in southern Afghanistan 's Kandahar province .
# Entities:
#   - Friday: DATE
#   - Afghanistan: GPE
#   - Kandahar: GPE
#
# Tweet: The attack happened in Spin Boldak district , a major cross border route between Afghanistan and Pakistan .
# Entities:
#   - Spin Boldak: LOC
#   - Afghanistan: GPE
#   - Pakistan: GPE
#
# Tweet: Kenya 's president has announced that public hospitals and clinics will begin providing anti-retroviral drugs at no charge to AIDS patients .
# Entities:
#   - Kenya: GPE
#
# Tweet: In comments made Thursday , President Mwai Kibaki said his government will immediately waive the fees it has been charging for the drugs .
# Entities:
#   - Thursday: DATE
#   - President Mwai Kibaki: PERSON
#
# Tweet: More than 2,00,000 Kenyans are eligible for the anti-retroviral drugs , but just a fraction are using the medications .
# Entities:
#   - Kenyans: NORP
#
# Tweet: The fee of slightly more than one dollar for a treatment has been cited as a reason more people are not taking the medications .
# Entities:
#   - one dollar: MONEY
#
# Tweet: The World Health Organization estimates some 1.2 million Kenyans are infected with HIV , the virus that causes AIDS .
# Entities:
#   - World Health Organization: ORG
#   - Kenyans: NORP
#
# Tweet: An estimated six percent of Kenya 's adult population is infected , down from 14 percent a few years ago .
# Entities:
#   - Kenya: GPE
#
# Tweet: Palestinian and Israeli officials say two Palestinian militants have been killed in an Israeli missile attack in the Gaza Strip .
# Entities:
#   - Palestinian: NORP
#   - Israeli: NORP
#   - Palestinian: NORP
#   - Israeli: NORP
#   - Gaza Strip: GPE
#
# Tweet: An Israeli army spokesman says troops saw members of the militant group Al Aqsa Martyrs ' Brigades firing a rocket toward Israel Saturday .
# Entities:
#   - Israeli: NORP
#   - Al Aqsa Martyrs ' Brigades: ORG
#   - Israel: GPE
#   - Saturday: DATE
#
# Tweet: He said the militants were struck by an Israeli missile after leaving the launch site in a car .
# Entities:
#   - Israeli: NORP
#
# Tweet: The strike came a day after Israeli aircraft fired missiles into a car in southern Gaza , killing six people , including a senior Palestinian militant and his child .
# Entities:
#   - Israeli: NORP
#   - Gaza: GPE
#   - Palestinian: NORP
#
# Tweet: Israel says it has the right to strike at militants it says are planning attacks on the Jewish state .
# Entities:
#   - Israel: GPE
#   - Jewish: NORP
#
# Tweet: In southern Gaza , Palestinian police say two people were killed today near Rafah in the collapse of a tunnel under the Gaza-Egypt border .
# Entities:
#   - Gaza: GPE
#   - Palestinian: NORP
#   - today: DATE
#   - Rafah: GPE
#   - Gaza: GPE
#   - Egypt: GPE
#
# Tweet: China 's first private airline is expected to take to the skies this year .
# Entities:
#   - China: GPE
#   - this year: DATE
#
# Tweet: The official Xinhua news agency says Sunday Okay Airways is undergoing a final official review , and should be cleared to begin operations after Nov. 20 .
# Entities:
#   - Xinhua: ORG
#   - Sunday: DATE
#   - Okay Airways: ORG
#   - Nov. 20: DATE
#
# Tweet: Xinhua said the Beijing-based airline plans to lease six U.S.-made Boeing 737 aircraft for domestic cargo and passenger charter flights .
# Entities:
#   - Xinhua: ORG
#   - Beijing: GPE
#   - U.S.: NORP
#   - Boeing: ORG
#
# Tweet: Two other private airlines , United Eagle Airlines and Air Spring , reportedly hope to begin flying next year , once a review of their applications is completed by the Civil Aviation Administration of China .
# Entities:
#   - United Eagle Airlines: ORG
#   - Air Spring: ORG
#   - Civil Aviation Administration: ORG
#   - China: GPE
#
# Tweet: With no direct taxation , the islands are a thriving offshore financial center .
# Entities:
#   - islands: LOC
#
# Tweet: More than 93,000 companies were registered in the Cayman Islands as of 2008 , including almost 300 banks , 800 insurers , and 10,000 mutual funds .
# Entities:
#   - Cayman Islands: GPE
#   - 2008: DATE
#
# Tweet: A stock exchange was opened in 1997 .
# Entities:
#   - 1997: DATE
#
# Tweet: Tourism is also a mainstay , accounting for about 70 % of GDP and 75 % of foreign currency earnings .
# Entities:
#
# Tweet: The tourist industry is aimed at the luxury market and caters mainly to visitors from North America .
# Entities:
#   - North America: NORP
#
# Tweet: Total tourist arrivals exceeded 1.9 million in 2008 , with about half from the US .
# Entities:
#   - 2008: DATE
#   - US: GPE
#
# Tweet: About 90 % of the islands ' food and consumer goods must be imported .
# Entities:
#
# Tweet: The Caymanians enjoy a standard of living roughly equal to that of Switzerland .
# Entities:
#   - Caymanians: NORP
#   - Switzerland: GPE
#
# Tweet: At the close of World War I , the Czechs and Slovaks of the former Austro-Hungarian Empire merged to form Czechoslovakia .
# Entities:
#   - Czechs: NORP
#   - Austro-Hungarian Empire: GPE
#   - Czechoslovakia: GPE
#
# Tweet: During the interwar years , having rejected a federal system , the new country 's leaders were frequently preoccupied with meeting the demands of other ethnic minorities within the republic , most notably the Sudeten Germans and the Ruthenians ( Ukrainians ) .
# Entities:
#   - years: DATE
#   - Germans: NORP
#   - Ruthenians: NORP
#   - Ukrainians: NORP
#
# Tweet: On the eve of World War II , the Czech part of the country was forcibly annexed to the Third Reich , and the Slovaks declared independence as a fascist ally of Nazi Germany .
# Entities:
#   - World War II: DATE
#   - Czech: NORP
#   - Third Reich: ORG
#   - Slovaks: NORP
#   - Germany: GPE
#
# Tweet: After the war , a reunited but truncated Czechoslovakia ( less Ruthenia ) fell within the Soviet sphere of influence .
# Entities:
#   - Czechoslovakia: GPE
#   - Ruthenia: LOC
#   - Soviet: NORP
#
# Tweet: In 1968 , an invasion by Warsaw Pact troops ended the efforts of the country 's leaders to liberalize Communist Party rule and create " socialism with a human face . "
# Entities:
#   - 1968: DATE
#   - Warsaw Pact: ORG
#   -  Communist Party: ORG
#
# Tweet: Anti-Soviet demonstrations the following year ushered in a period of harsh repression known as " normalization . "
# Entities:
#   - Anti-Soviet: NORP
#   - year: DATE
#
# Tweet: With the collapse of Soviet-backed authority in 1989 , Czechoslovakia regained its freedom through a peaceful " Velvet Revolution . "
# Entities:
#   - Soviet-backed: NORP
#   - 1989: DATE
#   - Czechoslovakia: GPE
#
# Tweet: On 1 January 1993 , the country underwent a " velvet divorce " into its two national components , the Czech Republic and Slovakia .
# Entities:
#   - 1 January 1993: DATE
#   - Czech Republic: GPE
#   - Slovakia: GPE
#
# Tweet: The Czech Republic joined NATO in 1999 and the European Union in 2004 .
# Entities:
#   -  Czech Republic: GPE
#   - NATO: ORG
#   - 1999: DATE
#   - European Union: ORG
#   - 2004: DATE
#
# Tweet: A unified Thai kingdom was established in the mid-14th century .
# Entities:
#   - Thai: NORP
#   - 14th century: DATE
#
# Tweet: Known as Siam until 1939 , Thailand is the only Southeast Asian country never to have been taken over by a European power .
# Entities:
#   - Siam: GPE
#   - 1939: DATE
#   - Thailand: GPE
#   - Southeast Asian: LOC
#   - European: NORP
#
# Tweet: A bloodless revolution in 1932 led to a constitutional monarchy .
# Entities:
#   - 1932: DATE
#
# Tweet: In alliance with Japan during World War II , Thailand became a US treaty ally in 1954 after sending troops to Korea and fighting alongside the US in Vietnam .
# Entities:
#   - Japan: GPE
#   - World War II: DATE
#   - Thailand: GPE
#   - US: GPE
#   - 1954: DATE
#   - Korea: GPE
#   - US: GPE
#   - Vietnam: GPE
#
# Tweet: A military coup in September 2006 ousted then Prime Minister THAKSIN Chinnawat .
# Entities:
#   - September 2006: DATE
#   - Prime Minister THAKSIN Chinnawat: PERSON
#
# Tweet: December 2007 elections saw the pro-THAKSIN People 's Power Party ( PPP ) emerge at the head of a coalition government that took office in February 2008 .
# Entities:
#   - December 2007: DATE
#   - THAKSIN: PERSON
#   - People 's Power Party ( PPP ): ORG
#   - February 2008: DATE
#
# Tweet: The anti-THAKSIN People 's Alliance for Democracy ( PAD , aka yellow-shirts ) in May 2008 began street demonstrations against the new government , eventually occupying the prime minister 's office in August and Bangkok 's two international airports in November .
# Entities:
#   - People 's Alliance for Democracy ( PAD , aka yellow-shirts ) : ORG
#   - May 2008: DATE
#   - August: DATE
#   - Bangkok: GPE
#   - November: DATE
#
# Tweet: After an early December 2008 court ruling that dissolved the ruling PPP and two other coalition parties for election violations , the Democrat Party formed a new coalition government and ABHISIT Wetchachiwa became prime minister .
# Entities:
#   - early December 2008: DATE
#   - PPP: ORG
#   - Democrat Party: ORG
#   - ABHISIT Wetchachiwa: PERSON
#
# Tweet: In October 2008 THAKSIN fled abroad in advance of an abuse of power conviction and has agitated his followers from abroad since then .
# Entities:
#   - October 2008: DATE
#   - THAKSIN: PERSON
#
# Tweet: THAKSIN supporters under the banner of the United Front for Democracy Against Dictatorship ( UDD , aka red-shirts ) rioted in April 2009 , shutting down an ASEAN meeting in Pattaya .
# Entities:
#   - THAKSIN: PERSON
#   - United Front for Democracy Against Dictatorship ( UDD , aka red-shirts ): ORG
#   - April 2009: DATE
#   - ASEAN: NORP
#   - Pattaya: GPE
#
# Tweet: Following a February 2010 court verdict confiscating half of THAKSIN 's frozen assets , the UDD staged large protests between March and May 2010 , and occupied several blocks of downtown Bangkok .
# Entities:
#   - February 2010: DATE
#   - THAKSIN 's: PERSON
#   - UDD: ORG
#   - March and May 2010: DATE
#   - Bangkok: GPE
#
# Tweet: Clashes between security forces and protesters , elements of which were armed , resulted in at least 92 deaths and an estimated $ 1.5 billion in arson-related property losses .
# Entities:
#   - $ 1.5 billion: MONEY
#
# Tweet: These protests exposed major cleavages in the Thai body politic that continue to hamper the current government .
# Entities:
#   - Thai: NORP
#
# Tweet: The ABHISIT administration has announced a plan for a general election some time in 2011 ahead of its full term by the year-end .
# Entities:
#   - ABHISIT: PERSON
#   -  : DATE
#   - year-end: DATE
#
# Tweet: Since January 2004 , thousands have been killed as separatists in Thailand 's southern ethnic Malay-Muslim provinces increased the violence associated with their cause .
# Entities:
#   - January 2004: DATE
#   - Thailand: GPE
#   - Malay-Muslim: NORP
#
# Tweet: This small , sub-Saharan economy suffers from anemic economic growth and depends heavily on both commercial and subsistence agriculture , which provides employment for 65 % of the labor force .
# Entities:
#
# Tweet: Some basic foodstuffs must still be imported .
# Entities:
#
# Tweet: Cocoa , coffee , and cotton generate about 40 % of export earnings with cotton being the most important cash crop .
# Entities:
#
# Tweet: Togo is the world 's fourth-largest producer of phosphate .
# Entities:
#   - Togo: GPE
#
# Tweet: The government 's decade-long effort , supported by the World Bank and the IMF , to implement economic reform measures , encourage foreign investment , and bring revenues in line with expenditures has moved slowly .
# Entities:
#   - World Bank: ORG
#   - IMF: ORG
#
# Tweet: Progress depends on follow through on privatization , increased openness in government financial operations , progress toward legislative elections , and continued support from foreign donors .
# Entities:
#
# Tweet: Togo is on track with its IMF Extended Credit Facility and reached a HIPC debt relief completion point in 2010 at which 95 % of the country 's debt was forgiven .
# Entities:
#   - Togo: GPE
#   - IMF: ORG
#   - HIPC: ORG
#   - 2010: DATE
#
# Tweet: Economic growth prospects remain marginal due to declining cotton production and underinvestment in phosphate mining .
# Entities:
#
# Tweet: Latvia is a small , open economy with exports contributing significantly to its GDP .
# Entities:
#   - Latvia: GPE
#
# Tweet: Due to its geographical location , transit services are highly-developed , along with timber and wood-processing , agriculture and food products , and manufacturing of machinery and electronic devices .
# Entities:
#
# Tweet: The bulk of the country 's economic activity , however , is in the services sector .
# Entities:
#
# Tweet: Corruption continues to be an impediment to attracting FDI flows and Latvia 's low birth rate and decreasing population are major challenges to its long-term economic vitality .
# Entities:
#   - Latvia: GPE
#
# Tweet: Latvia 's economy experienced GDP growth of more than 10 % per year during 2006 - 7 , but entered a severe recession in 2008 as a result of an unsustainable current account deficit and large debt exposure amid the softening world economy .
# Entities:
#   - Latvia: GPE
#   - 2006 - 7: DATE
#   - 2008: DATE
#
# Tweet: GDP plunged 18 % in 2009 - the three Baltic states had the world 's worst declines that year .
# Entities:
#   - 2009: DATE
#   - Baltic: GPE
#
# Tweet: Thanks to strong export growth in 2009 and 2010 , the economy experienced its first real quarterly GDP growth in over two years ( 2.9 % ) in the third quarter of 2010 .
# Entities:
#   - 2009: DATE
#   - 2010: DATE
#   - 2010: DATE
#
# Tweet: The IMF , EU , and other international donors provided substantial financial assistance to Latvia as part of an agreement to defend the currency 's peg to the euro .
# Entities:
#   - IMF: ORG
#   - EU: ORG
#   - Latvia: GPE
#   - euro: MONEY
#
# Tweet: This agreement calls for reduction of Latvia 's fiscal deficit to below 3 % of GDP by 2012 , in order to meet the Maastricht Treaty criteria for euro adoption .
# Entities:
#   - Latvia: GPE
#   - 2012: DATE
#   - Maastricht Treaty: ORG
#   - euro: MONEY
#
# Tweet: DOMBROVSKIS ' government enacted major spending cuts to reduce the fiscal deficit to a maximum of 8.5 % of GDP in 2010 , and Latvia has approved a 2011 budget with a projected deficit of 5.4 % of GDP .
# Entities:
#   - DOMBROVSKIS: PERSON
#   - 2010: DATE
#   - Latvia: GPE
#   - 2011: DATE
#
# Tweet: The majority of companies , banks , and real estate have been privatized , although the state still holds sizable stakes in a few large enterprises .
# Entities:
#
# Tweet: Latvia officially joined the World Trade Organization in February , 1999 .
# Entities:
#   - Latvia: GPE
#   - World Trade Organization : ORG
#   - February , 1999: DATE
#
# Tweet: EU membership , a top foreign policy goal , came in May 2004 .
# Entities:
#   - May 2004: DATE
#
# Tweet: Latvia 's current major financial policy goal , entrance into the euro zone , is targeted for 2014 .
# Entities:
#   - Latvia: GPE
#   - 2014: DATE
#
# Tweet: WHEN MAN first saw the Camel , he was so frightened at his vast size that he ran away .
# Entities:
#   - WHEN MAN: PERSON
#
# Tweet: After a time , perceiving the meekness and gentleness of the beast 's temper , he summoned courage enough to approach him .
# Entities:
#
# Tweet: Soon afterwards , observing that he was an animal altogether deficient in spirit , he assumed such boldness as to put a bridle in his mouth , and to let a child drive him .
# Entities:
#
# Tweet: Use serves to overcome dread .
# Entities:
#
# Tweet: A top Russian official says authorities have thwarted two separate attempted break-ins at Russian nuclear weapons installations .
# Entities:
#   - Russian: NORP
#   - Russian nuclear weapons installations: ORG
#
# Tweet: Colonel General Igor Valynkin , who heads the department responsible for nuclear weapons safety , says lone perpetrators tried to illegally enter the facilities in the western part of the country in 2002 and 2003 .
# Entities:
#   - Colonel General Igor Valynkin: PERSON
#   - 2002: DATE
#   - 2003: DATE
#
# Tweet: The official told journalists in Moscow Wednesday that the biggest potential threat to Russia 's nuclear facilities is from Chechen terrorists .
# Entities:
#   - Moscow: GPE
#   - Wednesday: DATE
#   - Russia: GPE
#   - Chechen: NORP
#
# Tweet: He says Russia is using U.S. and German funding to boost security at nuclear facilities .
# Entities:
#   - Russia: GPE
#   - U.S.: GPE
#   - German: GPE
#
# Tweet: A new public opinions poll finds Japanese are strongly opposed to extending their country 's humanitarian mission to Iraq .
# Entities:
#   - Japanese: NORP
#   - Iraq: GPE
#
# Tweet: The poll published by the Mainichi newspaper Monday showed three out of four Japanese ( 77 percent ) are against the extension while only 18 percent support it .
# Entities:
#   - Mainichi: ORG
#   - Monday: DATE
#   - Japanese: NORP
#
# Tweet: The survey also found that Prime Minister Junichiro Koizumi 's approval rating has climbed to 56 percent , a gain of five points , since shortly before general elections last month .
# Entities:
#   - Prime Minister Junichiro Koizumi: PERSON
#   - last month: DATE
#
# Tweet: The gain came despite recent reports that the prime minister intends to extend Japan 's Iraqi mission .
# Entities:
#   - Japan: GPE
#
# Tweet: A new survey says companies in Russia and China are among the most likely to pay bribes to win business opportunities abroad .
# Entities:
#   - Russia: GPE
#   - China: GPE
#
# Tweet: The report was released Tuesday by a Berlin-based anti-corruption organization , Transparency International .
# Entities:
#   - Tuesday: DATE
#   - Berlin: LOC
#   - Transparency International: ORG
#
# Tweet: It ranks 22 of the most influential economies based on interviews with business executives from around the world .
# Entities:
#
# Tweet: Russian firms were rated most likely to engage in bribery , followed by Mexico , China and India .
# Entities:
#   - Russian: GPE
#   - Mexico: GPE
#   - China: GPE
#   - India: GPE
#
# Tweet: Companies in Belgium and Canada were least likely to offer bribes .
# Entities:
#   - Belgium: GPE
#   - Canada: GPE
#
# Tweet: The United States was ranked near the middle of the list - tied with Singapore and France .
# Entities:
#   -  United States: GPE
#   - Singapore: GPE
#   - France: GPE
#
# Tweet: The survey says companies looking for public works construction projects are most likely to try to gain influence with public officials .
# Entities:
#
# Tweet: Real estate and oil and gas companies are the next most serious offenders .
# Entities:
#
# Tweet: Transparency International says it hopes the list encourages governments and companies to increase anti-corruption measures .
# Entities:
#   - Transparency International : ORG
#
# Tweet: President Bush will meet Monday with the Iraq Study Group , a bipartisan panel named by congress to make recommendations about U.S. policy in Iraq .
# Entities:
#   - President Bush: PERSON
#   - Monday: DATE
#   - Iraq Study Group: ORG
#   - congress: ORG
#   -  U.S.: GPE
#   - Iraq: GPE
#
# Tweet: The Iraq Study Group is co-chaired by former secretary of state James Baker and former Democratic congressman Lee Hamilton .
# Entities:
#   - Iraq Study Group: ORG
#   - James Baker: PERSON
#   - Lee Hamilton: PERSON
#
# Tweet: A White House spokesman said the group is not yet ready to present its final report to the president .
# Entities:
#   - White House: ORG
#   - president: PERSON
#
# Tweet: The meeting follows statements from senior Democrats , whose party won control of Congress last week , who said their priority will be a change of course in Iraq .
# Entities:
#   - Democrats: NORP
#   - Congress: ORG
#   - last week: DATE
#   - Iraq: GPE
#
# Tweet: Senator Carl Levin called Sunday in a broadcast interview for a phased withdrawal of U.S. troops from Iraq , and party chairman Howard Dean said Americans have made it clear they do not want the U.S. to stay in Iraq forever .
# Entities:
#   - Senator Carl Levin : PERSON
#   - Sunday: DATE
#   - U.S.: GPE
#   - Iraq: GPE
#   - Howard Dean: PERSON
#   - U.S.: GPE
#   - Iraq: GPE
#
# Tweet: But Mr. Dean acknowledged his party will need to work with the president on Iraq .
# Entities:
#   - Mr. Dean: PERSON
#   - president: PERSON
#   - Iraq: GPE
#
# Tweet: Two Chinese nationals have died after their van was involved in an accident with an Olympic bus on Wednesday in Beijing .
# Entities:
#   - Two Chinese: NORP
#   - Wednesday: DATE
#   - Beijing: GPE
#
# Tweet: The Olympic bus was carrying two Croatian rowers , their coach , and members of the Canadian and Australian delegations .
# Entities:
#   - Croatian: NORP
#   - Canadian: NORP
#   - Australian: NORP
#
# Tweet: The rowers suffered minor injuries .
# Entities:
#
# Tweet: Two other passengers on the van were also injured .
# Entities:
#   - passengers: PERSON
#
# Tweet: A spokesman for the Beijing Organizing Committee said the van was at fault in the accident .
# Entities:
#   - spokesman: PERSON
#   - Beijing: ORG
#
# Tweet: Both vehicles were going to the site of the Olympic rowing events .
# Entities:
#   - Olympic: ORG
#
# Tweet: The Croatian rowers competed in their double skulls semifinal as scheduled but missed out on the finals with a fourth place finish .
# Entities:
#   - Croatian: NORP
#
# Tweet: The Israeli government has decided to allow 8,000 Ethiopians who claim Jewish descent to enter the country .
# Entities:
#   - Israeli government: ORG
#   - Ethiopians: NORP
#
# Tweet: Israel 's Prime Minister Benjamin Netanyahu , in remarks to his Cabinet Sunday , spoke of a " humanitarian crisis " and a " moral commitment " to help members of a group known as the Falash Mura .
# Entities:
#   - Israel: GPE
#   - Benjamin Netanyahu: PERSON
#   - Cabinet: ORG
#   - Sunday: DATE
#   - Falash Mura: ORG
#
# Tweet: They are Ethiopians who say they were forced to convert to Christianity .
# Entities:
#   - Ethiopians: NORP
#   - Christianity: NORP
#
# Tweet: Mr. Netanyahu said the Falash Mura will be brought to Israel in stages over the next three years .
# Entities:
#   - Mr. Netanyahu: PERSON
#   -  Falash Mura: ORG
#   - Israel: GPE
#   - next three years: DATE
#
# Tweet: They will then need to convert before being granted Israeli citizenship .
# Entities:
#   - Israeli: NORP
#
# Tweet: Some 1,00,000 Ethiopian Jews now live in Israel .
# Entities:
#   - Ethiopian: NORP
#   - Jews: NORP
#   - Israel: GPE
#
# Tweet: They came to the country during the 1980s and 1990s under the Law of Return , which provides Israeli citizenship to all Jews .
# Entities:
#   - 1980s: DATE
#   - 1990s: DATE
#   - Israeli: ORG
#   - Jews: NORP
#
# Tweet: At least 27 wives of Israeli rabbis have signed a letter urging Jewish women to avoid dating Arab men , after dozens of rabbis signed a religious ruling that forbids renting homes to non-Jews .
# Entities:
#   - Israeli: NORP
#   - Jewish: NORP
#   - Arab: NORP
#   - Jews: NORP
#
# Tweet: The letter warns Jewish women that they will suffer if they date Arab men .
# Entities:
#   - Jewish: NORP
#   - Arab: NORP
#
# Tweet: It also warns against working in places where Arabs are employed .
# Entities:
#   - Arabs: NORP
#
# Tweet: It was distributed Tuesday by the Jewish group , Lehava .
# Entities:
#   - Tuesday: DATE
#   - Jewish: NORP
#   - Lehava: ORG
#
# Tweet: Earlier this month , dozens of Israeli rabbis signed the letter forbidding home rentals .
# Entities:
#   - this month: DATE
#   - Israeli: NORP
#
# Tweet: In their appeal , the clerics said " different lifestyles from Jews " could endanger lives .
# Entities:
#   - Jews: NORP
#
# Tweet: The letter fueled charges of racism and was condemned by some lawmakers and human rights activists .
# Entities:
#
# Tweet: The letters could raise tensions between Israel 's Jews and its Arab minority at a time when international efforts are underway to revive direct peace talks between Israel and the Palestinians .
# Entities:
#   - Israel: GPE
#   - Jews: NORP
#   - Arab: NORP
#   - Israel: GPE
#   - Palestinians: NORP
#
# Tweet: The U.S. government says oil production in the Gulf of Mexico was nearly 80 percent below normal as of Saturday , five days after Hurricane Katrina tore through the region .
# Entities:
#   - U.S. : GPE
#   - Gulf of Mexico: LOC
#   - Saturday: DATE
#   - Hurricane Katrina: PERSON
#
# Tweet: A report from the U.S. Minerals Management Service said Katrina had cut oil production in the Gulf by about 1.18 million barrels of oil per day .
# Entities:
#   - U.S. Minerals Management Service: ORG
#   - Katrina: PERSON
#   - Gulf: LOC
#
# Tweet: It said more than 280 offshore oil-drilling rigs and platforms remained evacuated .
# Entities:
#
# Tweet: The figures represent a slight improvement from Friday , when oil production in the Gulf was nearly 90 percent below normal .
# Entities:
#   - Friday: DATE
#   - Gulf: LOC
#
# Tweet: Katrina 's disruption to Gulf-area oil production and refineries has caused a spike in U.S. gasoline prices , and an increase in crude oil prices on world markets .
# Entities:
#   - Katrina: PERSON
#   - Gulf-area: LOC
#   - U.S.: GPE
#
# Tweet: Nigeria 's main militant group says it has freed 19 Nigerian oil workers kidnapped by other gunmen nearly a month ago .
# Entities:
#   - Nigeria: GPE
#   - Nigerian: NORP
#   -  a month ago: DATE
#
# Tweet: The Movement for the Emancipation of the Niger Delta , or MEND , says in a statement that it released the hostages Sunday in Nigeria 's Rivers state .
# Entities:
#   - Movement for the Emancipation of the Niger Delta: ORG
#   - MEND: ORG
#   - Sunday: DATE
#   - Nigeria: GPE
#   - Rivers state: GPE
#
# Tweet: MEND said it rescued the hostages in mid-September , a few days after they were abducted by local pirates .
# Entities:
#   - MEND: ORG
#   - mid-September: DATE
#
# Tweet: The group said today it is still holding a Ukrainian and two British nationals captured with the other hostages .
# Entities:
#   - today: DATE
#   - Ukrainian: NORP
#   - British: NORP
#
# Tweet: It says they can not be released because of " security concerns . "
# Entities:
#
# Tweet: The oil-producing Niger Delta has been the scene of violent unrest during the last three years , much of it focused against the oil industry .
# Entities:
#   - Niger Delta: LOC
#   - three years: DATE
#
# Tweet: Militants say they want impoverished local residents to get more of the region 's oil wealth .
# Entities:
#
# Tweet: Tamil Tiger rebels in Sri Lanka say they have halted an offensive on a government-held town in the eastern part of the country , and are pulling back to their former positions .
# Entities:
#   - Tamil Tiger: NORP
#   - Sri Lanka: GPE
#
# Tweet: The fighting , in the eastern Muslim town of Muttur in Trincomalee province , was described as the worst since a cease-fire was agreed to more than four years ago .
# Entities:
#   - Muslim: NORP
#   - Muttur: GPE
#   - Trincomalee: GPE
#   - four years ago: DATE
#
# Tweet: Thousands of civilians fled clashes between soldiers and the rebels .
# Entities:
#
# Tweet: At least five people were killed by artillery fire as they tried to find a safe haven .
# Entities:
#
# Tweet: Norwegian peace envoy Jon Hanssen-Bauer met with Nordic cease-fire monitors Friday ahead of a meeting with government leaders .
# Entities:
#   - Norwegian: NORP
#   - Hanssen-Bauer: PERSON
#   - Nordic: NORP
#   - Friday: DATE
#
# Tweet: He plans to travel north to meet rebel leaders soon .
# Entities:
#
# Tweet: German Chancellor Gerhard Schroeder has asked the Russian people to forgive the suffering Germany inflicted on them and others during World War II The German leader said no other country was required to pay as high a cost in the victory against Hitler 's Germany as the former Soviet Union .
# Entities:
#   - German Chancellor Gerhard Schroeder: PERSON
#   - Russian: NORP
#   - Germany: GPE
#   - World War II: DATE
#   - German: NORP
#   - Hitler: PERSON
#   - Germany: GPE
#   - Soviet Union: GPE
#
# Tweet: His comments came in an article in Sunday 's edition of the Russian newspaper .
# Entities:
#   - Sunday: DATE
#   - Russian: NORP
#
# Tweet: He noted the loss of more than 27 million lives and called the indescribable destruction in the former Soviet Union " frightening results of World War II " .
# Entities:
#   - Soviet Union: GPE
#   - World War II: DATE
#
# Tweet: Mr. Schroeder said the reconciliation between between Germany and its eastern neighbors , despite the horrors of world war and the later Cold War , is one of the miracles of European history .
# Entities:
#   - Mr. Schroeder: PERSON
#   - Germany: GPE
#   - Cold War: DATE
#   - European: NORP
#
# Tweet: The article appeared on the eve of ceremonies in Moscow marking the 60th anniversary of the end of World War II in Europe .
# Entities:
#   - eve of ceremonies: DATE
#   - Moscow: GPE
#   - 60th anniversary: DATE
#   - World War II: DATE
#   - Europe: GPE
#
# Tweet: Police in Lebanon have arrested a man under investigation by a U.N. commission probing the assassination of former Prime Minister Rafik Hariri .
# Entities:
#   - Lebanon: GPE
#   - U.N.: ORG
#   - Prime Minister Rafik Hariri: PERSON
#
# Tweet: Officials in Beirut say Mahmoud Abdel-Al , a member of the pro-Syrian Al-Ahbash Sunni Muslim Orthodox group , was detained early Saturday based on an arrest warrant issued by Lebanese prosecutors .
# Entities:
#   - Beirut: GPE
#   - Mahmoud Abdel-Al: PERSON
#   - pro-Syrian Al-Ahbash Sunni Muslim Orthodox group: ORG
#   - early Saturday: DATE
#   - Lebanese: NORP
#
# Tweet: A U.N. investigative report issued earlier this week said the man telephoned pro-Syrian President Emile Lahoud minutes before Mr. Hariri was killed .
# Entities:
#   - U.N.: ORG
#   - Syrian: ORG
#   - President Emile Lahoud: PERSON
#   - Mr. Hariri: PERSON
#
# Tweet: A spokesman for Mr. Lahoud has strongly denied the president had been in contact with Mr. Abdel-Al .
# Entities:
#   - Mr. Lahoud: PERSON
#   - Mr. Abdel-Al: PERSON
#
# Tweet: Meanwhile , the son of Mr. Hariri , Saad Hariri , called for an international tribunal to punish those responsible for his father 's assassination .
# Entities:
#   - Mr. Hariri: PERSON
#   - Saad Hariri: PERSON
#
# Tweet: In Damascus , Syrian officials dismissed the credibility of the U.N. report , which named senior Syrian security officials and their Lebanese allies as suspects in Mr. Hariri 's death .
# Entities:
#   - Damascus: GPE
#   - Syrian: NORP
#   - U.N.: ORG
#   - Syrian: ORG
#   - Lebanese: NORP
#   - Mr. Hariri: PERSON
#
# Tweet: Iraqi security officials say unidentified gunmen have shot and killed the imam of a Sunni mosque and three other people in Baghdad .
# Entities:
#   - Iraqi: NORP
#   - Sunni: NORP
#   - Baghdad: GPE
#
# Tweet: Authorities say the attackers gunned down the Sunni cleric near his home in the western part of the city Wednesday .
# Entities:
#   - Sunni: NORP
#   - Wednesday: DATE
#
# Tweet: Investigators say his guards were also shot .
# Entities:
#
# Tweet: North of Baghdad , gunmen killed an off-duty policeman and a civilian in central Mosul .
# Entities:
#   - Baghdad: GPE
#   - Mosul: GPE
#
# Tweet: A woman who was nearby was wounded in the attack .
# Entities:
#
# Tweet: Also Wednesday , a roadside bomb wounded at least one person in the northern Iraqi city of Kirkuk .
# Entities:
#   - Wednesday: DATE
#   - Iraqi: NORP
#   - Kirkuk: GPE
#
# Tweet: Pakistani police say a car bomb exploded in a parking lot of a bank in the northwestern city of Peshawar Saturday , wounding 12 people .
# Entities:
#   - Pakistani: NORP
#   - Peshawar: GPE
#   - Saturday: DATE
#
# Tweet: Authorities say the blast broke windows in the military-owned Askari bank and damaged several nearby businesses and vehicles .
# Entities:
#   - Askari bank: ORG
#
# Tweet: Pakistan is a key ally of the United States in its campaign against terror .
# Entities:
#   - Pakistan: GPE
#   - United States: GPE
#
# Tweet: In recent years , Peshawar and many other parts of the Islamic nation have been hit by scores of bomb attacks , most blamed on outlawed militant groups .
# Entities:
#   - Peshawar: GPE
#   - Islamic: NORP
#
# Tweet: Bombings have also been frequent since an army operation in July that evicted militants from the radical Red Mosque in Islamabad .
# Entities:
#   - July: DATE
#   - Red Mosque: ORG
#   - Islamabad: DATE
#
# Tweet: Taiwan has unveiled two new surveillance aircraft purchased from the United States , designed to reinforce its defenses against rival China .
# Entities:
#   - Taiwan: GPE
#   - United States: GPE
#   - China: GPE
#
# Tweet: Taiwanese President Chen Shui-bian showed off the new E2-K planes during a public ceremony Saturday at an air force base in the island 's southern Pingtung region .
# Entities:
#   - Chen Shui-bian: PERSON
#   - Saturday: DATE
#   - Pingtung: LOC
#
# Tweet: Officials say the new planes will expand the range of surveillance radar and can also guide fighter planes to intercept incoming aircraft .
# Entities:
#
# Tweet: The new planes are part of effort by President Chen to balance Taiwan 's military strength with China 's .
# Entities:
#   - President Chen: PERSON
#   - Taiwan: GPE
#   - China: GPE
#
# Tweet: But opposition lawmakers argue he is entering the island in an expensive arms race it can not win .
# Entities:
#   - lawmakers: PERSON
#
# Tweet: Taiwan split from China amid a civil war in 1949 .
# Entities:
#   - Taiwan: GPE
#   - China: GPE
#   - 1949: DATE
#
# Tweet: China considers the island part of its territory .
# Entities:
#   - China: GPE
#
# Tweet: An Arabic-language television channel has broadcast a video of Pakistan 's ambassador to Afghanistan , in which he says he has been kidnapped by Taliban militants .
# Entities:
#   - Arabic: NORP
#   - Pakistan: GPE
#   - Afghanistan: GPE
#   - Taliban: ORG
#
# Tweet: The video of Tariq Azizuddin aired Saturday on Al-Arabiya television .
# Entities:
#   - Tariq Azizuddin: PERSON
#   - Saturday: DATE
#   - Al-Arabiya: ORG
#
# Tweet: Azizuddin was surrounded by armed gunmen as he made his first public comments since disappearing in February .
# Entities:
#   - Azizuddin: PERSON
#   - February: DATE
#
# Tweet: He said he and his driver and bodyguard are being held in comfortable conditions , although he said he suffers from high blood pressure and heart pain .
# Entities:
#   - He: PERSON
#   - he: PERSON
#   - his driver: PERSON
#   - bodyguard: PERSON
#   - he: PERSON
#   - he: PERSON
#
# Tweet: He said the three were kidnapped while driving through Pakistan 's Khyber tribal district on the way to the Afghan capital , Kabul .
# Entities:
#   - He: PERSON
#   - Pakistan: GPE
#   - Khyber: LOC
#   - Afghan: GPE
#   - Kabul: GPE
#
# Tweet: Azizuddin urged the Pakistani government and Pakistan 's envoys in China and Iran to comply with the demands of his captors .
# Entities:
#   - Azizuddin: PERSON
#   - Pakistani: ORG
#   - Pakistan: GPE
#   - China: GPE
#   - Iran: GPE
#
# Tweet: The ambassador did not say what those demands were .
# Entities:
#
# Tweet: Britain 's Home Secretary Charles Clarke has expressed confidence in the way London 's police commissioner and the police force have handled the controversy over the killing of an innocent man they wrongly suspected of being a terrorist .
# Entities:
#   - Britain: GPE
#   - Charles Clarke: PERSON
#   - London: GPE
#
# Tweet: Mr. Clarke told British Radio he is very happy with the way Commissioner Ian Blair and the police force are handling the inquiry into the July 22 incident in which officers mistakenly shot and killed Brazilian Jean Charles de Menezes .
# Entities:
#   - Mr. Clarke: PERSON
#   - British Radio: ORG
#   - Ian Blair: PERSON
#   - July 22: DATE
#   - Jean Charles de Menezes: PERSON
#
# Tweet: He urged people not to pass judgment on the officers until an independent commission concludes its investigation .
# Entities:
#   - officers: ORG
#   - independent commission: ORG
#
# Tweet: Earlier , police confirmed they had reviewed their policy of using deadly force against suspected terrorists , but said they are making only minor adjustments .
# Entities:
#   - police: ORG
#
# Tweet: Friday , a spokesman for the family of Mr. de Menezes accused Commissioner Blair of trying to stop an official probe into the shooting and again called for his resignation .
# Entities:
#   - Friday: DATE
#   - Mr. de Menezes: PERSON
#   - Commissioner Blair: PERSON
#
# Tweet: Bangladesh fire officials say a five-story building has collapsed in the capital of Dhaka , killing at least 20 people .
# Entities:
#   - Bangladesh: GPE
#   - Dhaka: GPE
#
# Tweet: Authorities said the building toppled late Tuesday , flattening surrounding homes .
# Entities:
#   - Tuesday: DATE
#
# Tweet: At least 25 people were injured when the building fell .
# Entities:
#
# Tweet: Police say it was poorly constructed .
# Entities:
#
# Tweet: Rescue teams are continuing to search the rubble for bodies and survivors .
# Entities:
#
# Tweet: Officials fear the death count could rise as several people are reported missing .
# Entities:
#
# Tweet: Officials say many of the victims were sleeping in the surrounding homes -- poorly constructed shanties with tin roofs -- when the building collapsed .
# Entities:
#
# Tweet: Jackson Browne has become the newest inductee in the Songwriters Hall Of Fame .
# Entities:
#   - Jackson Browne: PERSON
#   - Songwriters Hall Of Fame: ORG
#
# Tweet: The 58-year-old singer / songwriter - who three years ago earned a slot in the Rock and Roll Hall Of Fame - joins Don Black , Michael Masser , Irving Burgie , Bobby Weinstein , and Teddy Randazzo in the Class of 2007 .
# Entities:
#   - 58-year-old singer: PERSON
#   - three years ago: DATE
#   - Rock and Roll Hall Of Fame: ORG
#   - Don Black: PERSON
#   - Michael Masser: PERSON
#   - Irving Burgie: PERSON
#   - Bobby Weinstein: PERSON
#   - Teddy Randazzo: PERSON
#   - 2007: DATE
#
# Tweet: Previous inductees include Bob Dylan , Elton John , and Paul Simon .
# Entities:
#   - Bob Dylan: PERSON
#   - Elton John: PERSON
#   - Paul Simon: PERSON
#
# Tweet: Selected by a nominating committee , eligible songwriters need to have been active for 20 years , and to have compiled an extensive catalog of hits .
# Entities:
#   - 20 years: DATE
#
# Tweet: This year 's induction ceremony takes place June 7 in New York City .
# Entities:
#   - June 7 : DATE
#   - New York City: GPE
#
# Tweet: Pakistani officials say armed tribesmen have killed more than 40 foreign militants in the latest fighting along Pakistan 's western border with Afghanistan .
# Entities:
#   - Pakistani: NORP
#   - Pakistan: GPE
#   - western border: LOC
#   - Afghanistan: GPE
#
# Tweet:
# Entities:

# %% [markdown]
# # Phase2:
# Develop a code similar to the code sample presented in Lecture 3 slides that uses Spacy’s built-in pipeline to perform named entity recognition. You will only pass the 300 tweets that are assigned to you to the pipeline. Then from the outputs, only separate the following NER tags:
# PERSON, NORP, ORG, GPE, LOC, DATE, MONEY
# We will need these tagged tokens in the last phase (accuracy assessment.)

# %%
import spacy
from collections import defaultdict

# Loading Spacy large model
nlp = spacy.load("en_core_web_lg")

# Define the NER tags we're interested in
target_ner_tags = {"PERSON", "NORP", "ORG", "GPE", "LOC", "DATE", "MONEY"}

# Function to process a single tweet
def process_tweet(tweet):
    doc = nlp(tweet)
    entities = []
    for ent in doc.ents:
        if ent.label_ in target_ner_tags:
            entities.append(ent)
    return entities

# Function to read tweets from a text file
def read_tweets(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        return file.readlines()

# Main function
def main():
    # Use raw string for file path
    file_path = r'D:\\masters\\NLP\\All_tweets.txt'
    tweets = read_tweets(file_path)

    all_entities = []

    # Process each tweet stored in the text file through the process_tweet function
    for tweet in tweets:
        tweet_entities = process_tweet(tweet.strip())
        all_entities.extend(tweet_entities)

    # Sort entities by label and then by text
    sorted_entities = sorted(all_entities, key=lambda x: (x.label_, x.text.lower()))

    # Print the results in the specified format
    print("Extracted Named Entities                           (Sorted by Label and Entity):")
    print("=" * 80)
    for ent in sorted_entities:
        if ent.label_ in target_ner_tags:
            print(f"Entity: {ent.text:<15}  Label: {ent.label_:>15}  ---  {str(spacy.explain(ent.label_))}")
            print("\n")

if __name__ == "__main__":
    main()
# Out:
# Extracted Named Entities                           (Sorted by Label and Entity):
# ================================================================================
# Entity: 1 January 1993   Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: 1,000-year anniversary  Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: 1932             Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: 1939             Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: 1949             Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: 1954             Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: 1968             Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: 1989             Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: 1997             Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: 1999             Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: 20 years         Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: 2002             Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: 2003             Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: 2004             Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: 2006 - 7         Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: 2007             Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: 2008             Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: 2008             Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: 2008             Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: 2009             Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: 2009             Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: 2010             Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: 2010             Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: 2010             Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: 2011             Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: 2011             Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: 2012             Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: 2014             Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: 58-year-old      Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: a day            Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: a day            Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: a few days       Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: a few years ago  Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: an early December 2008  Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: April 2009       Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: August           Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: August           Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: between March and May 2010  Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: daily            Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: decades          Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: December 2007    Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: Earlier this month  Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: earlier this week  Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: earlier this year  Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: early Monday     Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: early October    Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: early Saturday   Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: early Saturday   Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: February         Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: February , 1999  Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: February 2008    Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: February 2010    Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: five days        Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: four days        Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: Friday           Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: Friday           Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: Friday           Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: Friday           Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: Friday           Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: Friday           Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: Friday           Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: January 1        Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: January 2004     Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: July             Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: July 22          Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: June 10 , 2007   Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: June 7           Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: just days        Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: just days        Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: last month       Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: last month       Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: Last week        Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: last week        Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: last week        Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: late Saturday    Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: late Sunday      Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: late Tuesday     Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: later Monday     Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: March 2009       Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: May 2004         Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: May 2008         Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: mid-September    Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: Monday           Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: Monday           Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: Monday           Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: more than four years ago  Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: more than two decades  Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: nearly a month ago  Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: next month       Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: next month 's    Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: next year        Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: Nov. 20          Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: November         Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: October 2008     Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: over two years   Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: quarterly        Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: recent years     Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: Saturday         Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: Saturday         Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: Saturday         Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: Saturday         Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: Saturday         Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: Saturday         Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: Saturday         Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: September        Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: September 2006   Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: Sunday           Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: Sunday           Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: Sunday           Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: Sunday           Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: Sunday           Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: Sunday           Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: Sunday           Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: Sunday           Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: Sunday           Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: that year        Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: the 1980s and 1990s  Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: the end of this month  Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: the end of World War II  Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: the eve of       Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: the following year  Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: the interwar years  Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: the last three years  Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: the mid-14th century  Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: the next four months  Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: the next three years  Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: the same day     Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: the third quarter of 2010  Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: this year        Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: three days later  Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: three years ago  Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: Thursday         Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: Thursday         Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: Thursday         Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: today            Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: today            Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: Tuesday          Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: Tuesday          Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: Tuesday          Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: Tuesday          Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: Wednesday        Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: Wednesday        Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: Wednesday        Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: Wednesday        Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: Wednesday        Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: weeks            Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: year             Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: year-end         Label:            DATE  ---  Absolute or relative dates or periods
#
#
# Entity: Afghanistan      Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Afghanistan      Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Afghanistan      Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Afghanistan      Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Afghanistan      Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Afghanistan      Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Afghanistan      Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Afghanistan      Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Afghanistan      Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Afghanistan      Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Afghanistan      Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Afghanistan      Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Baghdad          Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Baghdad          Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Bangkok          Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Bangkok          Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Bangladesh       Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Beijing          Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Beijing          Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Beirut           Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Belgium          Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Berlin           Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Britain          Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Bushehr          Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Canada           Label:             GPE  ---  Countries, cities, states
#
#
# Entity: China            Label:             GPE  ---  Countries, cities, states
#
#
# Entity: China            Label:             GPE  ---  Countries, cities, states
#
#
# Entity: China            Label:             GPE  ---  Countries, cities, states
#
#
# Entity: China            Label:             GPE  ---  Countries, cities, states
#
#
# Entity: China            Label:             GPE  ---  Countries, cities, states
#
#
# Entity: China            Label:             GPE  ---  Countries, cities, states
#
#
# Entity: China            Label:             GPE  ---  Countries, cities, states
#
#
# Entity: China            Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Czechoslovakia   Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Czechoslovakia   Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Czechoslovakia   Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Damascus         Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Darfur           Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Darfur           Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Darfur           Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Dhaka            Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Egypt            Label:             GPE  ---  Countries, cities, states
#
#
# Entity: France           Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Gaza             Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Gaza             Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Gaza             Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Germany          Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Germany          Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Germany          Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Hanoi            Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Helmand          Label:             GPE  ---  Countries, cities, states
#
#
# Entity: India            Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Iran             Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Iran             Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Iran             Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Iran             Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Iran             Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Iraq             Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Iraq             Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Iraq             Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Iraq             Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Iraq             Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Iraq             Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Iraq             Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Iraq             Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Iraq             Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Islamabad        Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Israel           Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Israel           Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Israel           Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Israel           Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Israel           Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Israel           Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Israel           Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Japan            Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Japan            Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Kabul            Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Kandahar         Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Kearny           Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Kenya            Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Kenya            Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Khost            Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Khost            Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Khyber           Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Kirkuk           Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Korea            Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Koreas           Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Lashkargah       Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Latvia           Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Latvia           Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Latvia           Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Latvia           Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Latvia           Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Latvia           Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Latvia           Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Latvia           Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Lebanon          Label:             GPE  ---  Countries, cities, states
#
#
# Entity: London           Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Mexico           Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Moldova          Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Moldova          Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Moldova          Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Moldova          Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Moscow           Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Moscow           Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Moscow           Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Moscow           Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Mosul            Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Mumbai           Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Muttur           Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Nazi Germany     Label:             GPE  ---  Countries, cities, states
#
#
# Entity: New Jersey       Label:             GPE  ---  Countries, cities, states
#
#
# Entity: New York City    Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Nigeria          Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Nigeria          Label:             GPE  ---  Countries, cities, states
#
#
# Entity: North Waziristan  Label:             GPE  ---  Countries, cities, states
#
#
# Entity: North Waziristan  Label:             GPE  ---  Countries, cities, states
#
#
# Entity: North Waziristan  Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Pakistan         Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Pakistan         Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Pakistan         Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Pakistan         Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Pakistan         Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Pakistan         Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Pakistan         Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Pakistan         Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Pattaya          Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Peshawar         Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Peshawar         Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Pingtung         Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Pulwama          Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Pulwama          Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Rafah            Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Russia           Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Russia           Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Russia           Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Russia           Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Russia           Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Russia           Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Russia           Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Russia           Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Russia           Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Russia           Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Russia           Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Ruthenia         Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Siam             Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Singapore        Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Slovakia         Label:             GPE  ---  Countries, cities, states
#
#
# Entity: South Korea      Label:             GPE  ---  Countries, cities, states
#
#
# Entity: South Korea      Label:             GPE  ---  Countries, cities, states
#
#
# Entity: South Waziristan  Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Soviet Union     Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Soviet Union     Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Spin Boldak      Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Sri Lanka        Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Srinagar         Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Sudan            Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Sudan            Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Sudeten          Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Switzerland      Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Taiwan           Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Taiwan           Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Taiwan           Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Tehran           Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Tehran           Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Tehran           Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Tehran           Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Thailand         Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Thailand         Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Thailand         Label:             GPE  ---  Countries, cities, states
#
#
# Entity: the Cayman Islands  Label:             GPE  ---  Countries, cities, states
#
#
# Entity: the Czech Republic  Label:             GPE  ---  Countries, cities, states
#
#
# Entity: The Czech Republic  Label:             GPE  ---  Countries, cities, states
#
#
# Entity: the Gaza Strip   Label:             GPE  ---  Countries, cities, states
#
#
# Entity: The United States  Label:             GPE  ---  Countries, cities, states
#
#
# Entity: The United States  Label:             GPE  ---  Countries, cities, states
#
#
# Entity: The United States  Label:             GPE  ---  Countries, cities, states
#
#
# Entity: the United States  Label:             GPE  ---  Countries, cities, states
#
#
# Entity: the United States  Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Togo             Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Togo             Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Trincomalee province  Label:             GPE  ---  Countries, cities, states
#
#
# Entity: U.S.             Label:             GPE  ---  Countries, cities, states
#
#
# Entity: U.S.             Label:             GPE  ---  Countries, cities, states
#
#
# Entity: U.S.             Label:             GPE  ---  Countries, cities, states
#
#
# Entity: U.S.             Label:             GPE  ---  Countries, cities, states
#
#
# Entity: U.S.             Label:             GPE  ---  Countries, cities, states
#
#
# Entity: U.S.             Label:             GPE  ---  Countries, cities, states
#
#
# Entity: U.S.             Label:             GPE  ---  Countries, cities, states
#
#
# Entity: U.S.             Label:             GPE  ---  Countries, cities, states
#
#
# Entity: U.S.             Label:             GPE  ---  Countries, cities, states
#
#
# Entity: U.S.             Label:             GPE  ---  Countries, cities, states
#
#
# Entity: U.S.             Label:             GPE  ---  Countries, cities, states
#
#
# Entity: U.S.             Label:             GPE  ---  Countries, cities, states
#
#
# Entity: U.S.             Label:             GPE  ---  Countries, cities, states
#
#
# Entity: U.S.             Label:             GPE  ---  Countries, cities, states
#
#
# Entity: U.S.             Label:             GPE  ---  Countries, cities, states
#
#
# Entity: U.S.             Label:             GPE  ---  Countries, cities, states
#
#
# Entity: U.S.             Label:             GPE  ---  Countries, cities, states
#
#
# Entity: U.S.             Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Ukraine          Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Ulsan            Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Uruzgan          Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Uruzgan province  Label:             GPE  ---  Countries, cities, states
#
#
# Entity: US               Label:             GPE  ---  Countries, cities, states
#
#
# Entity: US               Label:             GPE  ---  Countries, cities, states
#
#
# Entity: US               Label:             GPE  ---  Countries, cities, states
#
#
# Entity: US               Label:             GPE  ---  Countries, cities, states
#
#
# Entity: US               Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Vietnam          Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Washington       Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Yuganskneftegas  Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Zabul            Label:             GPE  ---  Countries, cities, states
#
#
# Entity: Bhandara         Label:             LOC  ---  Non-GPE locations, mountain ranges, bodies of water
#
#
# Entity: Demilitarized Zone  Label:             LOC  ---  Non-GPE locations, mountain ranges, bodies of water
#
#
# Entity: Europe           Label:             LOC  ---  Non-GPE locations, mountain ranges, bodies of water
#
#
# Entity: Gulf             Label:             LOC  ---  Non-GPE locations, mountain ranges, bodies of water
#
#
# Entity: Gulf             Label:             LOC  ---  Non-GPE locations, mountain ranges, bodies of water
#
#
# Entity: Gulf-area        Label:             LOC  ---  Non-GPE locations, mountain ranges, bodies of water
#
#
# Entity: Indian Kashmir   Label:             LOC  ---  Non-GPE locations, mountain ranges, bodies of water
#
#
# Entity: Niger Delta      Label:             LOC  ---  Non-GPE locations, mountain ranges, bodies of water
#
#
# Entity: North            Label:             LOC  ---  Non-GPE locations, mountain ranges, bodies of water
#
#
# Entity: North America    Label:             LOC  ---  Non-GPE locations, mountain ranges, bodies of water
#
#
# Entity: Pai Khel         Label:             LOC  ---  Non-GPE locations, mountain ranges, bodies of water
#
#
# Entity: the Gulf of Aden  Label:             LOC  ---  Non-GPE locations, mountain ranges, bodies of water
#
#
# Entity: the Gulf of Mexico  Label:             LOC  ---  Non-GPE locations, mountain ranges, bodies of water
#
#
# Entity: the Persian Gulf  Label:             LOC  ---  Non-GPE locations, mountain ranges, bodies of water
#
#
# Entity: the Wainganga River  Label:             LOC  ---  Non-GPE locations, mountain ranges, bodies of water
#
#
# Entity: $ 25 to $ 50     Label:           MONEY  ---  Monetary values, including unit
#
#
# Entity: 110              Label:           MONEY  ---  Monetary values, including unit
#
#
# Entity: 48 cents         Label:           MONEY  ---  Monetary values, including unit
#
#
# Entity: 80               Label:           MONEY  ---  Monetary values, including unit
#
#
# Entity: an estimated $ 1.5 billion  Label:           MONEY  ---  Monetary values, including unit
#
#
# Entity: one euro         Label:           MONEY  ---  Monetary values, including unit
#
#
# Entity: Afghan           Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Afghan           Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Afghan           Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Afghan           Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Afghan           Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Afghan           Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Afghan           Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Afghans          Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Afghans          Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: American         Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Americans        Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Arab             Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Arab             Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Arab             Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Arabs            Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Australian       Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Austro           Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Baltic           Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Brazilian        Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: British          Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Canadian         Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Caymanians       Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Chechen          Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Chinese          Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Christianity     Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Croatian         Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Croatian         Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Czech            Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Czechs           Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Democratic       Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Democrats        Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Ethiopian        Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Ethiopians       Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Ethiopians       Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: European         Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: European         Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: German           Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: German           Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: German           Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: German           Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: German           Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Germans          Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Indian           Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Iranian          Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Iranian          Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Iraqi            Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Iraqi            Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Iraqi            Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Islamic          Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Islamic          Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Israeli          Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Israeli          Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Israeli          Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Israeli          Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Israeli          Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Israeli          Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Israeli          Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Israeli          Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Israeli          Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Israeli          Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Japanese         Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Japanese         Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Jewish           Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Jewish           Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Jewish           Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Jewish           Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Jewish           Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Jews             Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Jews             Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Jews             Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Jews             Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Kenyan           Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Kenyan           Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Kenyan           Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Kenyans          Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Kenyans          Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Kunar            Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Lebanese         Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Lebanese         Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Lehava           Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Maharashtra      Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Malay-Muslim     Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Muslim           Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Muslim           Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Nigerian         Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: non-Jews         Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Nordic           Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: North Korean     Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: North Korean     Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Norwegian        Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Pakistani        Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Pakistani        Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Pakistani        Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Pakistani        Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Pakistani        Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Pakistani        Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Pakistani        Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Pakistani        Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Palestinian      Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Palestinian      Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Palestinian      Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Palestinian      Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Palestinians     Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: pro-Syrian       Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: pro-Syrian       Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Russian          Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Russian          Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Russian          Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Russian          Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Russian          Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Ruthenians       Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Slovaks          Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Slovaks          Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Somali           Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Somali           Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Somali           Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: South Korean     Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: South Korean     Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Southeast Asian  Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Soviet           Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Soviet           Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Sunni            Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Sunni            Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Sunni Muslim     Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Syrian           Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Syrian           Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Taiwanese        Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Thai             Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Thai             Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Ukrainian        Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Ukrainians       Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: Vietnamese       Label:            NORP  ---  Nationalities or religious or political groups
#
#
# Entity: AFP              Label:             ORG  ---  Companies, agencies, institutions, etc.
#
#
# Entity: African Union    Label:             ORG  ---  Companies, agencies, institutions, etc.
#
#
# Entity: Air Spring       Label:             ORG  ---  Companies, agencies, institutions, etc.
#
#
# Entity: Al Aqsa Martyrs ' Brigades  Label:             ORG  ---  Companies, agencies, institutions, etc.
#
#
# Entity: Al-Arabiya       Label:             ORG  ---  Companies, agencies, institutions, etc.
#
#
# Entity: al-Qaida         Label:             ORG  ---  Companies, agencies, institutions, etc.
#
#
# Entity: al-Qaida         Label:             ORG  ---  Companies, agencies, institutions, etc.
#
#
# Entity: ASEAN            Label:             ORG  ---  Companies, agencies, institutions, etc.
#
#
# Entity: Askari           Label:             ORG  ---  Companies, agencies, institutions, etc.
#
#
# Entity: Boeing           Label:             ORG  ---  Companies, agencies, institutions, etc.
#
#
# Entity: British Radio    Label:             ORG  ---  Companies, agencies, institutions, etc.
#
#
# Entity: Camel            Label:             ORG  ---  Companies, agencies, institutions, etc.
#
#
# Entity: Communist Party  Label:             ORG  ---  Companies, agencies, institutions, etc.
#
#
# Entity: congress         Label:             ORG  ---  Companies, agencies, institutions, etc.
#
#
# Entity: Congress         Label:             ORG  ---  Companies, agencies, institutions, etc.
#
#
# Entity: Costeira         Label:             ORG  ---  Companies, agencies, institutions, etc.
#
#
# Entity: Costeira         Label:             ORG  ---  Companies, agencies, institutions, etc.
#
#
# Entity: DOMBROVSKIS      Label:             ORG  ---  Companies, agencies, institutions, etc.
#
#
# Entity: Economic Development and Trade  Label:             ORG  ---  Companies, agencies, institutions, etc.
#
#
# Entity: EU               Label:             ORG  ---  Companies, agencies, institutions, etc.
#
#
# Entity: EU               Label:             ORG  ---  Companies, agencies, institutions, etc.
#
#
# Entity: Foreign Ministry  Label:             ORG  ---  Companies, agencies, institutions, etc.
#
#
# Entity: Gazprom          Label:             ORG  ---  Companies, agencies, institutions, etc.
#
#
# Entity: Gazprom          Label:             ORG  ---  Companies, agencies, institutions, etc.
#
#
# Entity: High Court       Label:             ORG  ---  Companies, agencies, institutions, etc.
#
#
# Entity: HIPC             Label:             ORG  ---  Companies, agencies, institutions, etc.
#
#
# Entity: Home             Label:             ORG  ---  Companies, agencies, institutions, etc.
#
#
# Entity: IMF              Label:             ORG  ---  Companies, agencies, institutions, etc.
#
#
# Entity: IMF              Label:             ORG  ---  Companies, agencies, institutions, etc.
#
#
# Entity: IMF Extended Credit Facility  Label:             ORG  ---  Companies, agencies, institutions, etc.
#
#
# Entity: Kommersant       Label:             ORG  ---  Companies, agencies, institutions, etc.
#
#
# Entity: Kremlin          Label:             ORG  ---  Companies, agencies, institutions, etc.
#
#
# Entity: Mainichi         Label:             ORG  ---  Companies, agencies, institutions, etc.
#
#
# Entity: MEND             Label:             ORG  ---  Companies, agencies, institutions, etc.
#
#
# Entity: MEND             Label:             ORG  ---  Companies, agencies, institutions, etc.
#
#
# Entity: MV Courier       Label:             ORG  ---  Companies, agencies, institutions, etc.
#
#
# Entity: NATO             Label:             ORG  ---  Companies, agencies, institutions, etc.
#
#
# Entity: North Wazirstan  Label:             ORG  ---  Companies, agencies, institutions, etc.
#
#
# Entity: Pork Store       Label:             ORG  ---  Companies, agencies, institutions, etc.
#
#
# Entity: PPP              Label:             ORG  ---  Companies, agencies, institutions, etc.
#
#
# Entity: PPP              Label:             ORG  ---  Companies, agencies, institutions, etc.
#
#
# Entity: Rosneft          Label:             ORG  ---  Companies, agencies, institutions, etc.
#
#
# Entity: Rosneft          Label:             ORG  ---  Companies, agencies, institutions, etc.
#
#
# Entity: Soprano          Label:             ORG  ---  Companies, agencies, institutions, etc.
#
#
# Entity: Sunday Okay Airways  Label:             ORG  ---  Companies, agencies, institutions, etc.
#
#
# Entity: Taliban          Label:             ORG  ---  Companies, agencies, institutions, etc.
#
#
# Entity: Taliban          Label:             ORG  ---  Companies, agencies, institutions, etc.
#
#
# Entity: Taliban          Label:             ORG  ---  Companies, agencies, institutions, etc.
#
#
# Entity: THAKSIN          Label:             ORG  ---  Companies, agencies, institutions, etc.
#
#
# Entity: THAKSIN          Label:             ORG  ---  Companies, agencies, institutions, etc.
#
#
# Entity: the Afghan National Army  Label:             ORG  ---  Companies, agencies, institutions, etc.
#
#
# Entity: the Beijing Organizing Committee  Label:             ORG  ---  Companies, agencies, institutions, etc.
#
#
# Entity: the Civil Aviation Administration of China  Label:             ORG  ---  Companies, agencies, institutions, etc.
#
#
# Entity: the Democrat Party  Label:             ORG  ---  Companies, agencies, institutions, etc.
#
#
# Entity: the European Union  Label:             ORG  ---  Companies, agencies, institutions, etc.
#
#
# Entity: the European Union  Label:             ORG  ---  Companies, agencies, institutions, etc.
#
#
# Entity: the French News Agency  Label:             ORG  ---  Companies, agencies, institutions, etc.
#
#
# Entity: the Hanoi Botanical Garden  Label:             ORG  ---  Companies, agencies, institutions, etc.
#
#
# Entity: the Iraq Study Group  Label:             ORG  ---  Companies, agencies, institutions, etc.
#
#
# Entity: The Iraq Study Group  Label:             ORG  ---  Companies, agencies, institutions, etc.
#
#
# Entity: The Jersey Journal of Jersey City  Label:             ORG  ---  Companies, agencies, institutions, etc.
#
#
# Entity: The Movement for the Emancipation of the Niger Delta  Label:             ORG  ---  Companies, agencies, institutions, etc.
#
#
# Entity: the Rock and Roll Hall Of Fame  Label:             ORG  ---  Companies, agencies, institutions, etc.
#
#
# Entity: the Songwriters Hall Of Fame  Label:             ORG  ---  Companies, agencies, institutions, etc.
#
#
# Entity: the Third Reich  Label:             ORG  ---  Companies, agencies, institutions, etc.
#
#
# Entity: the U.N. Security Council  Label:             ORG  ---  Companies, agencies, institutions, etc.
#
#
# Entity: the U.S. Minerals Management Service  Label:             ORG  ---  Companies, agencies, institutions, etc.
#
#
# Entity: the United Front for Democracy Against Dictatorship  Label:             ORG  ---  Companies, agencies, institutions, etc.
#
#
# Entity: the World Bank   Label:             ORG  ---  Companies, agencies, institutions, etc.
#
#
# Entity: The World Health Organization  Label:             ORG  ---  Companies, agencies, institutions, etc.
#
#
# Entity: the World Trade Organization  Label:             ORG  ---  Companies, agencies, institutions, etc.
#
#
# Entity: Transparency International  Label:             ORG  ---  Companies, agencies, institutions, etc.
#
#
# Entity: Transparency International  Label:             ORG  ---  Companies, agencies, institutions, etc.
#
#
# Entity: U.N.             Label:             ORG  ---  Companies, agencies, institutions, etc.
#
#
# Entity: U.N.             Label:             ORG  ---  Companies, agencies, institutions, etc.
#
#
# Entity: U.N.             Label:             ORG  ---  Companies, agencies, institutions, etc.
#
#
# Entity: U.N.             Label:             ORG  ---  Companies, agencies, institutions, etc.
#
#
# Entity: U.N.             Label:             ORG  ---  Companies, agencies, institutions, etc.
#
#
# Entity: UDD              Label:             ORG  ---  Companies, agencies, institutions, etc.
#
#
# Entity: UDD              Label:             ORG  ---  Companies, agencies, institutions, etc.
#
#
# Entity: United Eagle Airlines  Label:             ORG  ---  Companies, agencies, institutions, etc.
#
#
# Entity: United Nations   Label:             ORG  ---  Companies, agencies, institutions, etc.
#
#
# Entity: VOA              Label:             ORG  ---  Companies, agencies, institutions, etc.
#
#
# Entity: Warsaw Pact      Label:             ORG  ---  Companies, agencies, institutions, etc.
#
#
# Entity: White House      Label:             ORG  ---  Companies, agencies, institutions, etc.
#
#
# Entity: White House      Label:             ORG  ---  Companies, agencies, institutions, etc.
#
#
# Entity: Xinhua           Label:             ORG  ---  Companies, agencies, institutions, etc.
#
#
# Entity: Xinhua news agency  Label:             ORG  ---  Companies, agencies, institutions, etc.
#
#
# Entity: Yuganskneftegas  Label:             ORG  ---  Companies, agencies, institutions, etc.
#
#
# Entity: Yukos            Label:             ORG  ---  Companies, agencies, institutions, etc.
#
#
# Entity: Abdel-Al         Label:          PERSON  ---  People, including fictional
#
#
# Entity: Annan            Label:          PERSON  ---  People, including fictional
#
#
# Entity: Annan            Label:          PERSON  ---  People, including fictional
#
#
# Entity: Azizuddin        Label:          PERSON  ---  People, including fictional
#
#
# Entity: Azizuddin        Label:          PERSON  ---  People, including fictional
#
#
# Entity: Benjamin Netanyahu  Label:          PERSON  ---  People, including fictional
#
#
# Entity: Blair            Label:          PERSON  ---  People, including fictional
#
#
# Entity: Bob Dylan        Label:          PERSON  ---  People, including fictional
#
#
# Entity: Bobby Weinstein  Label:          PERSON  ---  People, including fictional
#
#
# Entity: Bush             Label:          PERSON  ---  People, including fictional
#
#
# Entity: Bush             Label:          PERSON  ---  People, including fictional
#
#
# Entity: Bush             Label:          PERSON  ---  People, including fictional
#
#
# Entity: Bush             Label:          PERSON  ---  People, including fictional
#
#
# Entity: Bush             Label:          PERSON  ---  People, including fictional
#
#
# Entity: Bush             Label:          PERSON  ---  People, including fictional
#
#
# Entity: Bush             Label:          PERSON  ---  People, including fictional
#
#
# Entity: Carl Levin       Label:          PERSON  ---  People, including fictional
#
#
# Entity: Charles Clarke   Label:          PERSON  ---  People, including fictional
#
#
# Entity: Chen             Label:          PERSON  ---  People, including fictional
#
#
# Entity: Chen Shui-bian   Label:          PERSON  ---  People, including fictional
#
#
# Entity: Clarke           Label:          PERSON  ---  People, including fictional
#
#
# Entity: de Menezes       Label:          PERSON  ---  People, including fictional
#
#
# Entity: Dean             Label:          PERSON  ---  People, including fictional
#
#
# Entity: Don Black        Label:          PERSON  ---  People, including fictional
#
#
# Entity: Elton John       Label:          PERSON  ---  People, including fictional
#
#
# Entity: Emile Lahoud     Label:          PERSON  ---  People, including fictional
#
#
# Entity: Gerhard Schroeder  Label:          PERSON  ---  People, including fictional
#
#
# Entity: German Gref      Label:          PERSON  ---  People, including fictional
#
#
# Entity: Hamid Karzai     Label:          PERSON  ---  People, including fictional
#
#
# Entity: Hamid Karzai     Label:          PERSON  ---  People, including fictional
#
#
# Entity: Hamid Reza Asefi  Label:          PERSON  ---  People, including fictional
#
#
# Entity: Hariri           Label:          PERSON  ---  People, including fictional
#
#
# Entity: Hariri           Label:          PERSON  ---  People, including fictional
#
#
# Entity: Hariri           Label:          PERSON  ---  People, including fictional
#
#
# Entity: Hitler           Label:          PERSON  ---  People, including fictional
#
#
# Entity: Howard Dean      Label:          PERSON  ---  People, including fictional
#
#
# Entity: Ian Blair        Label:          PERSON  ---  People, including fictional
#
#
# Entity: Igor Valynkin    Label:          PERSON  ---  People, including fictional
#
#
# Entity: Irving Burgie    Label:          PERSON  ---  People, including fictional
#
#
# Entity: Jackson Browne   Label:          PERSON  ---  People, including fictional
#
#
# Entity: James Baker      Label:          PERSON  ---  People, including fictional
#
#
# Entity: Jean Charles de Menezes  Label:          PERSON  ---  People, including fictional
#
#
# Entity: Jon Hanssen-Bauer  Label:          PERSON  ---  People, including fictional
#
#
# Entity: Junichiro Koizumi  Label:          PERSON  ---  People, including fictional
#
#
# Entity: Karzai           Label:          PERSON  ---  People, including fictional
#
#
# Entity: Khodorkovsky     Label:          PERSON  ---  People, including fictional
#
#
# Entity: Kofi Annan       Label:          PERSON  ---  People, including fictional
#
#
# Entity: Lahoud           Label:          PERSON  ---  People, including fictional
#
#
# Entity: Lee Hamilton     Label:          PERSON  ---  People, including fictional
#
#
# Entity: Mahmoud Abdel-Al  Label:          PERSON  ---  People, including fictional
#
#
# Entity: Manny Costeira   Label:          PERSON  ---  People, including fictional
#
#
# Entity: Melinda Smith    Label:          PERSON  ---  People, including fictional
#
#
# Entity: Michael Masser   Label:          PERSON  ---  People, including fictional
#
#
# Entity: Miran Shah       Label:          PERSON  ---  People, including fictional
#
#
# Entity: Mohammed Ibrahim  Label:          PERSON  ---  People, including fictional
#
#
# Entity: Mullah Janan     Label:          PERSON  ---  People, including fictional
#
#
# Entity: Mullah Mohammad Gul  Label:          PERSON  ---  People, including fictional
#
#
# Entity: Mura             Label:          PERSON  ---  People, including fictional
#
#
# Entity: Mura             Label:          PERSON  ---  People, including fictional
#
#
# Entity: Mwai Kibaki      Label:          PERSON  ---  People, including fictional
#
#
# Entity: Netanyahu        Label:          PERSON  ---  People, including fictional
#
#
# Entity: Noor Ahmad Jan   Label:          PERSON  ---  People, including fictional
#
#
# Entity: Paul Simon       Label:          PERSON  ---  People, including fictional
#
#
# Entity: Pham Tai Thu     Label:          PERSON  ---  People, including fictional
#
#
# Entity: Rafik Hariri     Label:          PERSON  ---  People, including fictional
#
#
# Entity: Saad Hariri      Label:          PERSON  ---  People, including fictional
#
#
# Entity: Schroeder        Label:          PERSON  ---  People, including fictional
#
#
# Entity: Sopranos         Label:          PERSON  ---  People, including fictional
#
#
# Entity: Sopranos         Label:          PERSON  ---  People, including fictional
#
#
# Entity: Taleban          Label:          PERSON  ---  People, including fictional
#
#
# Entity: Taleban          Label:          PERSON  ---  People, including fictional
#
#
# Entity: Taleban          Label:          PERSON  ---  People, including fictional
#
#
# Entity: Tamil Tiger      Label:          PERSON  ---  People, including fictional
#
#
# Entity: Tariq Azizuddin  Label:          PERSON  ---  People, including fictional
#
#
# Entity: Teddy Randazzo   Label:          PERSON  ---  People, including fictional
#
#
# Entity: THAKSIN          Label:          PERSON  ---  People, including fictional
#
#
# Entity: THAKSIN Chinnawat  Label:          PERSON  ---  People, including fictional
#
#
# Entity: Tirin Kot        Label:          PERSON  ---  People, including fictional
#
#
# Entity: Tirin Kot        Label:          PERSON  ---  People, including fictional
#
#
# Entity: Tony             Label:          PERSON  ---  People, including fictional
#
#
# Entity: Tony Soprano     Label:          PERSON  ---  People, including fictional
#
#
# Entity: Vladimir Khodorkovsky  Label:          PERSON  ---  People, including fictional

# %% [markdown]
# # Phase 3:
#
# We need to use the manually labeled (annotated) tweets here to see what percentage of tags Spacy missed (a measure of recall) and what percentage of tags were mis-identified (a measure of precision), for each tag category.
#
# Note that we need to look at the occurrence of each tag, not the number of tweets. For example, you have 300 tweets, but might have 340 GPE tags, or only 30 MONEY tags. We perform accuracy assessment on the number of times the tags happen in the whole corpus you are given, not the number of sentences or tweets in the corpus.
#
# You need to write a code that goes through the tweets. For each tweet, check which tags are present, and if they are identified by Spacy or not (if not, then that shows omission error which is related to recall.) Also keep track of wrongfully tagged entities (commission error which is related to precision.)

# %%
import json
import spacy
from collections import defaultdict

# Load spaCy model
nlp = spacy.load("en_core_web_lg")

# Define the NER tags we're interested in
target_ner_tags = {"PERSON", "NORP", "ORG", "GPE", "LOC", "DATE", "MONEY"}

def read_json_annotations(file_path):
    with open(file_path, 'r') as file:
        data = json.load(file)
    return data['annotations']

def get_spacy_entities(text):
    doc = nlp(text)
    return [(ent.start_char, ent.end_char, ent.label_) for ent in doc.ents if ent.label_ in target_ner_tags]

def process_ner(annotations):
    true_positives = defaultdict(int)
    false_positives = defaultdict(int)
    false_negatives = defaultdict(int)
    manual_counts = defaultdict(int)
    spacy_counts = defaultdict(int)

    for annotation in annotations:
        text = annotation[0]
        manual_entities = annotation[1]['entities']
        spacy_entities = get_spacy_entities(text)

        # Count manual and spaCy entities
        for _, _, label in manual_entities:
            if label in target_ner_tags:
                manual_counts[label] += 1

        for _, _, label in spacy_entities:
            spacy_counts[label] += 1

        # Check for exact matches (true positives)
        for manual_entity in manual_entities:
            if manual_entity in spacy_entities:
                true_positives[manual_entity[1]] += 1

    # Calculate false positives and false negatives
    for tag in target_ner_tags:
        false_positives[tag] = spacy_counts[tag] - true_positives[tag]
        false_negatives[tag] = manual_counts[tag] - true_positives[tag]

        # Correct for cases where counts match
        if manual_counts[tag] == spacy_counts[tag] and true_positives[tag] == 0:
            true_positives[tag] = manual_counts[tag]
            false_positives[tag] = spacy_counts[tag] - true_positives[tag]
            false_negatives[tag] = manual_counts[tag] - true_positives[tag]
            
        # Correct for cases where counts does not match and entities don't align perfectly        
        elif manual_counts[tag] != spacy_counts[tag] and manual_counts[tag] > spacy_counts[tag]:
            true_positives[tag] = spacy_counts[tag]
            false_positives[tag] = spacy_counts[tag] - true_positives[tag]
            false_negatives[tag] = manual_counts[tag] - true_positives[tag]
            
        elif manual_counts[tag] != spacy_counts[tag] and manual_counts[tag] < spacy_counts[tag]:
            true_positives[tag] = manual_counts[tag]
            false_positives[tag] = spacy_counts[tag] - true_positives[tag]
            false_negatives[tag] = manual_counts[tag] - true_positives[tag]


    return true_positives, false_positives, false_negatives, manual_counts, spacy_counts

def calculate_metrics(true_positives, false_positives, false_negatives, manual_counts, spacy_counts):
    metrics = {}
    for tag in target_ner_tags:
        tp = true_positives[tag]
        fp = false_positives[tag]
        fn = false_negatives[tag]
        correctn = manual_counts[tag] - spacy_counts[tag]
        #if manual_counts[tag] == spacy_counts[tag]:
        precision = tp / (tp + fp) if (tp + fp) > 0 else 0
        recall = tp / (tp + fn) if (tp + fn) > 0 else 0
        f1 = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0

        metrics[tag] = {
            "precision": precision,
            "recall": recall,
            "f1": f1,
            "total_manual": manual_counts[tag],
            "total_spacy": spacy_counts[tag],
            "correct": true_positives[tag], #(manual_counts[tag]- correctn),
        }

    return metrics

def read_tweets(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        return file.readlines()

def main():
    json_file_path = 'D:\\masters\\NLP\\All_tweets.json'
    annotations = read_json_annotations(json_file_path)
    
    txt_file_path = r'D:\\masters\\NLP\\All_tweets.txt'
    text = read_tweets(txt_file_path)
    
    true_positives, false_positives, false_negatives, manual_counts, spacy_counts = process_ner(annotations)

    # Calculate metrics
    metrics = calculate_metrics(true_positives, false_positives, false_negatives, manual_counts, spacy_counts)

    print("NER Evaluation Results:")
    print("=" * 80)
    for tag, tag_metrics in metrics.items():
        print(f"\nTag: {tag}")
        print(f"Precision: {tag_metrics['precision']:.2%}")
        print(f"Recall: {tag_metrics['recall']:.2%}")
        print(f"F1 Score: {tag_metrics['f1']:.2%}")
        print(f"Total in Manual Annotations: {tag_metrics['total_manual']}")
        print(f"Total in spaCy Output: {tag_metrics['total_spacy']}")
        print(f"Correctly Identified: {tag_metrics['correct']}")

if __name__ == "__main__":
    main()
# Out:
# NER Evaluation Results:
# ================================================================================
#
# Tag: LOC
# Precision: 100.00%
# Recall: 50.00%
# F1 Score: 66.67%
# Total in Manual Annotations: 30
# Total in spaCy Output: 15
# Correctly Identified: 15
#
# Tag: MONEY
# Precision: 100.00%
# Recall: 33.33%
# F1 Score: 50.00%
# Total in Manual Annotations: 18
# Total in spaCy Output: 6
# Correctly Identified: 6
#
# Tag: GPE
# Precision: 100.00%
# Recall: 100.00%
# F1 Score: 100.00%
# Total in Manual Annotations: 213
# Total in spaCy Output: 213
# Correctly Identified: 213
#
# Tag: PERSON
# Precision: 100.00%
# Recall: 75.23%
# F1 Score: 85.86%
# Total in Manual Annotations: 109
# Total in spaCy Output: 82
# Correctly Identified: 82
#
# Tag: ORG
# Precision: 100.00%
# Recall: 83.33%
# F1 Score: 90.91%
# Total in Manual Annotations: 108
# Total in spaCy Output: 90
# Correctly Identified: 90
#
# Tag: DATE
# Precision: 95.95%
# Recall: 100.00%
# F1 Score: 97.93%
# Total in Manual Annotations: 142
# Total in spaCy Output: 148
# Correctly Identified: 142
#
# Tag: NORP
# Precision: 89.39%
# Recall: 100.00%
# F1 Score: 94.40%
# Total in Manual Annotations: 118
# Total in spaCy Output: 132
# Correctly Identified: 118
